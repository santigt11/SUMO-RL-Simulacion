# %% [markdown]
# # Experimento 2: Q-Learning con Variable Green Durations
#
# s = (nvehicles, twaiting, lqueue, rarrival). Acciones: 12 duraciones de verde (5-60s).
# Recompensa: penalizacion simple por tiempo promedio de espera.
#
# Configuracion:
# - 5000 epocas, num_seconds=100000, delta_time=5
# - Epsilon: 0.5 -> 0.05 con decay 0.9995 (por episodio)
# - Sin clipping de recompensa
# - Discretizador: 6/6/4/3 bins (432 estados x 12 acciones = 5184 total)
# - Experience Replay: buffer=2000, batch=64, update_freq=4
# - QLAgentConVisitas: tracking de visitas + early stopping por cobertura
# - Guarda ultimo modelo

# %%
import os
os.environ["LIBSUMO_AS_TRACI"] = "1"

# %%
import traci

# Limpiar conexiones zombie de ejecuciones anteriores
try:
    traci.close()
except:
    pass
# Out:
# Using libsumo as traci as requested by environment variable.

# %%
import argparse
import pandas as pd
import pickle
import sys
import numpy as np
import os
import gymnasium as gym
from sumo_rl import SumoEnvironment
from sumo_rl.agents import QLAgent
from sumo_rl.exploration import EpsilonGreedy
import seaborn as sns
import matplotlib.pyplot as plt

# %%
if 'SUMO_HOME' not in os.environ:
    os.environ['SUMO_HOME'] = '/usr/share/sumo'
tools = os.path.join(os.environ['SUMO_HOME'], 'tools')
sys.path.append(tools)

# %%
# Reward: tiempo de espera promedio por vehiculo
def recompensa_waiting_time(ts):
    """Penalizacion simple: tiempo promedio de espera por vehiculo."""
    ids = ts.sumo.vehicle.getIDList()
    waiting_time = np.mean([ts.sumo.vehicle.getWaitingTime(v) for v in ids]) if len(ids) > 0 else 0.0
    return -waiting_time


def reset_recompensa():
    """Resetear estado interno de la funcion de recompensa."""
    pass


# ========== VARIABLE GREEN WRAPPER ==========
class VariableGreenWrapper(gym.Wrapper):
    """Seleccion de duracion de verde (5-60s en pasos de 5s)."""
    DURACIONES = list(range(5, 65, 5))  # 12 acciones: 5-60s

    def __init__(self, env, delta_time=5):
        super().__init__(env)
        self.delta_time = delta_time
        self.action_space = gym.spaces.Discrete(len(self.DURACIONES))
        self._fase_actual = 0

    def step(self, action_idx):
        duracion = self.DURACIONES[action_idx]
        n_pasos = duracion // self.delta_time
        reward_acumulado = 0.0
        terminated = truncated = False
        info = {}
        for _ in range(n_pasos):
            obs, reward, terminated, truncated, info = self.env.step(self._fase_actual)
            reward_acumulado += reward
            if terminated or truncated:
                break
            if self.env.unwrapped.sumo.simulation.getMinExpectedNumber() == 0:
                break
        self._fase_actual = 1 - self._fase_actual
        return obs, reward_acumulado, terminated, truncated, info

    def reset(self, **kwargs):
        self._fase_actual = 0
        return self.env.reset(**kwargs)


# ========== REPLAY BUFFER ==========
class ReplayBuffer:
    """
    Buffer de experiencias para Q-learning con replay.
    buffer_size=2000, batch_size=64.
    """
    def __init__(self, buffer_size=2000):
        self.buffer_size = buffer_size
        self.buffer = []
        self.position = 0
        self.total_pushes = 0
        self.total_samples = 0

    def push(self, state, action, reward, next_state, done):
        experience = (state, action, reward, next_state, done)
        if len(self.buffer) < self.buffer_size:
            self.buffer.append(experience)
        else:
            self.buffer[self.position] = experience
        self.position = (self.position + 1) % self.buffer_size
        self.total_pushes += 1

    def sample(self, batch_size=64):
        if len(self.buffer) < batch_size:
            return self.buffer
        indices = np.random.choice(len(self.buffer), batch_size, replace=False)
        self.total_samples += batch_size
        return [self.buffer[i] for i in indices]

    def __len__(self):
        return len(self.buffer)

    def clear(self):
        self.buffer = []
        self.position = 0
        self.total_pushes = 0
        self.total_samples = 0

    def get_stats(self):
        if len(self.buffer) == 0:
            return {'size': 0, 'capacity': self.buffer_size, 'fill_ratio': 0.0,
                    'avg_reward': 0.0, 'total_pushes': self.total_pushes, 'total_samples': self.total_samples}
        rewards = [exp[2] for exp in self.buffer]
        return {
            'size': len(self.buffer), 'capacity': self.buffer_size,
            'fill_ratio': len(self.buffer) / self.buffer_size,
            'avg_reward': np.mean(rewards), 'min_reward': np.min(rewards), 'max_reward': np.max(rewards),
            'total_pushes': self.total_pushes, 'total_samples': self.total_samples
        }


# ========== Q-LAGENT WITH REPLAY ==========
class QLAgentWithReplay(QLAgent):
    """QLAgent extendido con experience replay."""
    def __init__(self, starting_state, state_space, action_space,
                 alpha, gamma, exploration_strategy,
                 replay_buffer, batch_size=64, update_freq=4):
        super().__init__(starting_state, state_space, action_space,
                        alpha, gamma, exploration_strategy)
        self.replay_buffer = replay_buffer
        self.batch_size = batch_size
        self.update_freq = update_freq
        self.step_count = 0

    def act(self):
        """Initialize state in Q-table if missing, then choose action."""
        state_tuple = tuple(self.state) if hasattr(self.state, '__iter__') else self.state
        if state_tuple not in self.q_table:
            self.q_table[state_tuple] = [0.0] * self.action_space.n
        return super().act()

    def learn_with_replay(self, next_state, reward, done):
        self.replay_buffer.push(self.state, self.action, reward, next_state, done)
        self.state = next_state
        self.step_count += 1
        if len(self.replay_buffer) >= self.batch_size and self.step_count % self.update_freq == 0:
            batch = self.replay_buffer.sample(self.batch_size)
            for state, action, reward, next_state, done in batch:
                self._update_q(state, action, reward, next_state, done)

    def _update_q(self, state, action, reward, next_state, done):
        s = tuple(state) if hasattr(state, '__iter__') else state
        ns = tuple(next_state) if hasattr(next_state, '__iter__') else next_state
        if s not in self.q_table:
            self.q_table[s] = [0.0] * self.action_space.n
        if ns not in self.q_table:
            self.q_table[ns] = [0.0] * self.action_space.n
        target = reward if done else reward + self.gamma * max(self.q_table[ns])
        self.q_table[s][action] += self.alpha * (target - self.q_table[s][action])


# ========== Q-LAGENT CON VISITAS ==========
class QLAgentConVisitas(QLAgentWithReplay):
    """QLAgent con conteo de visitas por estado."""
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.visitas = {}

    def act(self):
        estado = tuple(self.state) if hasattr(self.state, '__iter__') else self.state
        self.visitas[estado] = self.visitas.get(estado, 0) + 1
        if estado not in self.q_table:
            self.q_table[estado] = [0.0] * self.action_space.n
        return super().act()

# %%
# Cargar bin edges calibrados
_edges = np.load("../../Simulaciones_tiempos_fijos/V2_traci/resultados/bin_edges_calibrados.npz")
EDGES_NVEHICULOS = _edges["nvehiculos"]
EDGES_WAITING    = _edges["waiting"]
EDGES_QUEUE      = _edges["queue"]
EDGES_ARRIVAL    = _edges["arrival"]


class TrafficStateWrapper(gym.Wrapper):
    """Estado discreto: (nvehiculos, twaiting, lqueue, rarrival) con edges calibrados."""
    observation_space = gym.spaces.MultiDiscrete([6, 6, 4, 3])

    def _compute_state(self):
        ids = self.env.unwrapped.sumo.vehicle.getIDList()
        n_vehiculos = len(ids)
        waiting = np.mean([self.env.unwrapped.sumo.vehicle.getWaitingTime(v) for v in ids]) if n_vehiculos > 0 else 0.0
        queue = self.env.unwrapped.traffic_signals[self.env.unwrapped.ts_ids[0]].get_total_queued()

        if not hasattr(self, '_ventana_llegadas'):
            self._ventana_llegadas = []
        arrival_step = self.env.unwrapped.sumo.simulation.getDepartedNumber()
        self._ventana_llegadas.append(arrival_step)
        if len(self._ventana_llegadas) > 6:
            self._ventana_llegadas.pop(0)
        arrival = sum(self._ventana_llegadas)

        bin_n = int(np.digitize(n_vehiculos, EDGES_NVEHICULOS))
        bin_w = int(np.digitize(waiting, EDGES_WAITING))
        bin_q = int(np.digitize(queue, EDGES_QUEUE))
        bin_a = int(np.digitize(arrival, EDGES_ARRIVAL))

        return (bin_n, bin_w, bin_q, bin_a)

    def reset(self, **kwargs):
        self._ventana_llegadas = []
        obs, info = self.env.reset(**kwargs)
        return self._compute_state(), info

    def step(self, action):
        obs, reward, terminated, truncated, info = self.env.step(action)
        return self._compute_state(), reward, terminated, truncated, info

# %%
NET = os.path.join("..", "..", "Simple_Intersection.net.xml")
ROU = os.path.join("..", "..", "Distribuciones", "Dist_Weibull_V2", "loja_intersection_weibull.rou.xml")
OUT_FOLDER = "resultados"

os.makedirs(OUT_FOLDER, exist_ok=True)

print(f"NET existe: {os.path.exists(NET)}")
print(f"ROU existe: {os.path.exists(ROU)}")
# Out:
# NET existe: True
# ROU existe: True

# %%
def get_args():
    prs = argparse.ArgumentParser(formatter_class=argparse.ArgumentDefaultsHelpFormatter)
    prs.add_argument("-route", dest="route", type=str, default=ROU)
    prs.add_argument("-net", dest="net", type=str, default=NET)
    prs.add_argument("-a", dest="alpha", type=float, default=0.1)
    prs.add_argument("-g", dest="gamma", type=float, default=0.95)
    prs.add_argument("-gui", action="store_true", default=False)
    prs.add_argument("-r", dest="reward", type=str, default='waiting_time')
    prs.add_argument("-runs", dest="runs", type=int, default=1)
    prs.add_argument("-episodes", dest="episodes", type=int, default=5000)
    prs.add_argument("-num_seconds", dest="num_seconds", type=int, default=100000)
    prs.add_argument("-min_epsilon", dest="min_epsilon", type=float, default=0.05)
    prs.add_argument("-initial_epsilon", dest="initial_epsilon", type=float, default=0.5)
    prs.add_argument("-decay", dest="decay", type=float, default=0.9995)
    return prs.parse_args(args=[])

# %%
if __name__ == '__main__':
    if 'args' not in dir():
        args = get_args()

    exploracion = EpsilonGreedy(
        initial_epsilon=args.initial_epsilon,
        min_epsilon=args.min_epsilon,
        decay=1.0  # sin decay interno, solo el loop controla por episodio
    )

    replay_buffer = ReplayBuffer(buffer_size=2000)

    import sys as _sys
    import os as _os
    _old_stderr = _sys.stderr
    _sys.stderr = open(_os.devnull, 'w')

    env_temp = SumoEnvironment(
        net_file=args.net,
        route_file=args.route,
        out_csv_name="temp",
        single_agent=True,
        delta_time=5,
        yellow_time=3,
        min_green=5,
        reward_fn=recompensa_waiting_time,
        additional_sumo_cmd="-W --no-step-log"
    )

    _sys.stderr = _old_stderr

    env_temp = VariableGreenWrapper(env_temp, delta_time=5)
    env_temp = TrafficStateWrapper(env_temp)
    obs_inicial, _ = env_temp.reset()

    agente = QLAgentConVisitas(
        starting_state=obs_inicial,
        state_space=env_temp.observation_space,
        action_space=env_temp.action_space,
        alpha=args.alpha,
        gamma=args.gamma,
        exploration_strategy=exploracion,
        replay_buffer=replay_buffer,
        batch_size=64,
        update_freq=4
    )

    env_temp.close()

    historial_recompensas = []
    cobertura_historial = []

    def cobertura_estabilizada(historial, ventana=5):
        return len(historial) >= ventana and historial[-1] <= historial[-ventana]

    print("Entrenamiento Q-Learning (12 duraciones de verde, reward waiting_time)...")
    for run in range(1, args.runs + 1):
        for episode in range(1, args.episodes + 1):
            reset_recompensa()

            _old_stderr2 = _sys.stderr
            _sys.stderr = open(_os.devnull, 'w')

            env = SumoEnvironment(
                net_file=args.net,
                route_file=args.route,
                out_csv_name="temp",
                single_agent=True,
                use_gui=args.gui,
                num_seconds=args.num_seconds,
                delta_time=5,
                yellow_time=3,
                min_green=5,
                reward_fn=recompensa_waiting_time,
                time_to_teleport=-1,
                additional_sumo_cmd="-W --no-step-log"
            )

            _sys.stderr = _old_stderr2

            env = VariableGreenWrapper(env, delta_time=5)
            env = TrafficStateWrapper(env)
            obs, _ = env.reset()
            try:
                agente.state = obs
                done = False
                recompensa_episodio = 0

                tiempo_final = 0
                while not done:
                    accion = agente.act()
                    next_obs, reward, terminated, truncated, info = env.step(accion)

                    agente.learn_with_replay(next_state=next_obs, reward=reward, done=terminated)
                    recompensa_episodio += reward

                    if env.unwrapped.sumo.simulation.getMinExpectedNumber() == 0:
                        tiempo_final = env.unwrapped.sim_step
                        break

                    done = terminated or truncated

                historial_recompensas.append(recompensa_episodio)

            finally:
                env.close()

            exploracion.epsilon = max(exploracion.epsilon * args.decay, args.min_epsilon)

            if episode % 100 == 0:
                cobertura = len(agente.q_table) / (6 * 6 * 4 * 3)
                cobertura_historial.append(cobertura)
                print(f"  Ep {episode:03d} | Rec: {recompensa_episodio:10.2f} | Epsilon: {exploracion.epsilon:.3f} | Vaciado: {tiempo_final:.0f}s | Cobertura: {cobertura:.1%}")
            else:
                print(f"  Ep {episode:03d} | Rec: {recompensa_episodio:10.2f} | Epsilon: {exploracion.epsilon:.3f} | Vaciado: {tiempo_final:.0f}s")

            if cobertura_estabilizada(cobertura_historial):
                print(f"Cobertura estabilizada en episodio {episode} - deteniendo entrenamiento")
                break

    with open(os.path.join(OUT_FOLDER, "ql_rec_queue.pkl"), 'wb') as f:
        pickle.dump(agente.q_table, f)
    print(f"\nModelo guardado en {os.path.join(OUT_FOLDER, 'ql_rec_queue.pkl')}")

    print("\n" + "="*60)
    print("ESTADISTICAS DEL ENTRENAMIENTO")
    print("="*60)
    print(f"Estados en Q-table: {len(agente.q_table)}")
    print(f"Total estados posibles: {6*6*4*3} (6/6/4/3 bins)")
    print(f"Cobertura final: {len(agente.q_table)/(6*6*4*3):.1%}")
    print(f"\nTop 10 estados mas visitados:")
    top_visitados = sorted(agente.visitas.items(), key=lambda x: x[1], reverse=True)[:10]
    for estado, visits in top_visitados:
        print(f"  {estado}: {visits} visitas")

    stats = replay_buffer.get_stats()
    print(f"\nExperience Replay Buffer:")
    print(f"Tamaño actual: {stats['size']} / {stats['capacity']}")
    print(f"Total experiencias: {stats['total_pushes']}")
# Out:
# Entrenamiento Q-Learning (12 duraciones de verde, reward waiting_time)...
#   Ep 001 | Rec: -1888775.00 | Epsilon: 0.500 | Vaciado: 3710s
#   Ep 002 | Rec: -1850707.00 | Epsilon: 0.500 | Vaciado: 3790s
#   Ep 003 | Rec: -2005624.00 | Epsilon: 0.499 | Vaciado: 3870s
#   Ep 004 | Rec: -1922332.00 | Epsilon: 0.499 | Vaciado: 3790s
#   Ep 005 | Rec: -2054895.00 | Epsilon: 0.499 | Vaciado: 3975s
#   Ep 006 | Rec: -1838855.00 | Epsilon: 0.499 | Vaciado: 3935s
#   Ep 007 | Rec: -2161911.00 | Epsilon: 0.498 | Vaciado: 3880s
#   Ep 008 | Rec: -1942480.00 | Epsilon: 0.498 | Vaciado: 3740s
#   Ep 009 | Rec: -2034611.00 | Epsilon: 0.498 | Vaciado: 3865s
#   Ep 010 | Rec: -2065071.00 | Epsilon: 0.498 | Vaciado: 3825s
#   Ep 011 | Rec: -1659919.00 | Epsilon: 0.497 | Vaciado: 4020s
#   Ep 012 | Rec: -2161816.00 | Epsilon: 0.497 | Vaciado: 3825s
#   Ep 013 | Rec: -1961962.00 | Epsilon: 0.497 | Vaciado: 3755s
#   Ep 014 | Rec: -2183782.00 | Epsilon: 0.497 | Vaciado: 3795s
#   Ep 015 | Rec: -1741025.00 | Epsilon: 0.496 | Vaciado: 3755s
#   Ep 016 | Rec: -1888745.00 | Epsilon: 0.496 | Vaciado: 3895s
#   Ep 017 | Rec: -2034821.00 | Epsilon: 0.496 | Vaciado: 3910s
#   Ep 018 | Rec: -1929171.00 | Epsilon: 0.496 | Vaciado: 3950s
#   Ep 019 | Rec: -2219093.00 | Epsilon: 0.495 | Vaciado: 4110s
#   Ep 020 | Rec: -2012768.00 | Epsilon: 0.495 | Vaciado: 3745s
#   Ep 021 | Rec: -1919769.00 | Epsilon: 0.495 | Vaciado: 3910s
#   Ep 022 | Rec: -1830848.00 | Epsilon: 0.495 | Vaciado: 4000s
#   Ep 023 | Rec: -2252476.00 | Epsilon: 0.494 | Vaciado: 3970s
#   Ep 024 | Rec: -1984730.00 | Epsilon: 0.494 | Vaciado: 3900s
#   Ep 025 | Rec: -1941110.00 | Epsilon: 0.494 | Vaciado: 3725s
#   Ep 026 | Rec: -2006594.00 | Epsilon: 0.494 | Vaciado: 3790s
#   Ep 027 | Rec: -2057158.00 | Epsilon: 0.493 | Vaciado: 3905s
#   Ep 028 | Rec: -2460998.00 | Epsilon: 0.493 | Vaciado: 4090s
#   Ep 029 | Rec: -2051608.00 | Epsilon: 0.493 | Vaciado: 3835s
#   Ep 030 | Rec: -2268669.00 | Epsilon: 0.493 | Vaciado: 4165s
#   Ep 031 | Rec: -1862001.00 | Epsilon: 0.492 | Vaciado: 3860s
#   Ep 032 | Rec: -2345541.00 | Epsilon: 0.492 | Vaciado: 3745s
#   Ep 033 | Rec: -1961363.00 | Epsilon: 0.492 | Vaciado: 3910s
#   Ep 034 | Rec: -2059771.00 | Epsilon: 0.492 | Vaciado: 4040s
#   Ep 035 | Rec: -1976471.00 | Epsilon: 0.491 | Vaciado: 3785s
#   Ep 036 | Rec: -2109676.00 | Epsilon: 0.491 | Vaciado: 3910s
#   Ep 037 | Rec: -2039536.00 | Epsilon: 0.491 | Vaciado: 3780s
#   Ep 038 | Rec: -2075827.00 | Epsilon: 0.491 | Vaciado: 3950s
#   Ep 039 | Rec: -2439495.00 | Epsilon: 0.490 | Vaciado: 3855s
#   Ep 040 | Rec: -1928060.00 | Epsilon: 0.490 | Vaciado: 3870s
#   Ep 041 | Rec: -2027459.00 | Epsilon: 0.490 | Vaciado: 3775s
#   Ep 042 | Rec: -2002910.00 | Epsilon: 0.490 | Vaciado: 3755s
#   Ep 043 | Rec: -2032844.00 | Epsilon: 0.489 | Vaciado: 3765s
#   Ep 044 | Rec: -2071255.00 | Epsilon: 0.489 | Vaciado: 3760s
#   Ep 045 | Rec: -1816265.00 | Epsilon: 0.489 | Vaciado: 3775s
#   Ep 046 | Rec: -2574968.00 | Epsilon: 0.489 | Vaciado: 4285s
#   Ep 047 | Rec: -2069565.00 | Epsilon: 0.488 | Vaciado: 3710s
#   Ep 048 | Rec: -2608397.00 | Epsilon: 0.488 | Vaciado: 4385s
#   Ep 049 | Rec: -2295601.00 | Epsilon: 0.488 | Vaciado: 3850s
#   Ep 050 | Rec: -1902783.00 | Epsilon: 0.488 | Vaciado: 3860s
#   Ep 051 | Rec: -2184918.00 | Epsilon: 0.487 | Vaciado: 3790s
#   Ep 052 | Rec: -2278221.00 | Epsilon: 0.487 | Vaciado: 4200s
#   Ep 053 | Rec: -1971842.00 | Epsilon: 0.487 | Vaciado: 3835s
#   Ep 054 | Rec: -1964959.00 | Epsilon: 0.487 | Vaciado: 3900s
#   Ep 055 | Rec: -1924478.00 | Epsilon: 0.486 | Vaciado: 3980s
#   Ep 056 | Rec: -2034048.00 | Epsilon: 0.486 | Vaciado: 4000s
#   Ep 057 | Rec: -2117765.00 | Epsilon: 0.486 | Vaciado: 3815s
#   Ep 058 | Rec: -2017591.00 | Epsilon: 0.486 | Vaciado: 3725s
#   Ep 059 | Rec: -2588813.00 | Epsilon: 0.485 | Vaciado: 4030s
#   Ep 060 | Rec: -2568325.00 | Epsilon: 0.485 | Vaciado: 3885s
#   Ep 061 | Rec: -2049916.00 | Epsilon: 0.485 | Vaciado: 3775s
#   Ep 062 | Rec: -2060142.00 | Epsilon: 0.485 | Vaciado: 3815s
#   Ep 063 | Rec: -2034281.00 | Epsilon: 0.484 | Vaciado: 4025s
#   Ep 064 | Rec: -1913899.00 | Epsilon: 0.484 | Vaciado: 3865s
#   Ep 065 | Rec: -1798774.00 | Epsilon: 0.484 | Vaciado: 3845s
#   Ep 066 | Rec: -1985221.00 | Epsilon: 0.484 | Vaciado: 4025s
#   Ep 067 | Rec: -2392897.00 | Epsilon: 0.484 | Vaciado: 4070s
#   Ep 068 | Rec: -2129238.00 | Epsilon: 0.483 | Vaciado: 3905s
#   Ep 069 | Rec: -2374754.00 | Epsilon: 0.483 | Vaciado: 3855s
#   Ep 070 | Rec: -1900725.00 | Epsilon: 0.483 | Vaciado: 3800s
#   Ep 071 | Rec: -2149296.00 | Epsilon: 0.483 | Vaciado: 3780s
#   Ep 072 | Rec: -2083802.00 | Epsilon: 0.482 | Vaciado: 3950s
#   Ep 073 | Rec: -2011594.00 | Epsilon: 0.482 | Vaciado: 3895s
#   Ep 074 | Rec: -2274865.00 | Epsilon: 0.482 | Vaciado: 3860s
#   Ep 075 | Rec: -1963688.00 | Epsilon: 0.482 | Vaciado: 3835s
#   Ep 076 | Rec: -2039760.00 | Epsilon: 0.481 | Vaciado: 3835s
#   Ep 077 | Rec: -1914762.00 | Epsilon: 0.481 | Vaciado: 4030s
#   Ep 078 | Rec: -2683778.00 | Epsilon: 0.481 | Vaciado: 4115s
#   Ep 079 | Rec: -1883409.00 | Epsilon: 0.481 | Vaciado: 3810s
#   Ep 080 | Rec: -2334280.00 | Epsilon: 0.480 | Vaciado: 4130s
#   Ep 081 | Rec: -2052141.00 | Epsilon: 0.480 | Vaciado: 4075s
#   Ep 082 | Rec: -1889333.00 | Epsilon: 0.480 | Vaciado: 3990s
#   Ep 083 | Rec: -1935635.00 | Epsilon: 0.480 | Vaciado: 3775s
#   Ep 084 | Rec: -1865960.00 | Epsilon: 0.479 | Vaciado: 3805s
#   Ep 085 | Rec: -2339481.00 | Epsilon: 0.479 | Vaciado: 3880s
#   Ep 086 | Rec: -1908139.00 | Epsilon: 0.479 | Vaciado: 3820s
#   Ep 087 | Rec: -1995593.00 | Epsilon: 0.479 | Vaciado: 3820s
#   Ep 088 | Rec: -2325312.00 | Epsilon: 0.478 | Vaciado: 4050s
#   Ep 089 | Rec: -1885856.00 | Epsilon: 0.478 | Vaciado: 3885s
#   Ep 090 | Rec: -1905631.00 | Epsilon: 0.478 | Vaciado: 3755s
#   Ep 091 | Rec: -2001497.00 | Epsilon: 0.478 | Vaciado: 3840s
#   Ep 092 | Rec: -2582271.00 | Epsilon: 0.478 | Vaciado: 4000s
#   Ep 093 | Rec: -2561449.00 | Epsilon: 0.477 | Vaciado: 3835s
#   Ep 094 | Rec: -1886286.00 | Epsilon: 0.477 | Vaciado: 3875s
#   Ep 095 | Rec: -2964752.00 | Epsilon: 0.477 | Vaciado: 4420s
#   Ep 096 | Rec: -1930345.00 | Epsilon: 0.477 | Vaciado: 3870s
#   Ep 097 | Rec: -1930180.00 | Epsilon: 0.476 | Vaciado: 3835s
#   Ep 098 | Rec: -2045115.00 | Epsilon: 0.476 | Vaciado: 3950s
#   Ep 099 | Rec: -2176911.00 | Epsilon: 0.476 | Vaciado: 3965s
#   Ep 100 | Rec: -1929117.00 | Epsilon: 0.476 | Vaciado: 3730s | Cobertura: 49.8%
#   Ep 101 | Rec: -2043557.00 | Epsilon: 0.475 | Vaciado: 3935s
#   Ep 102 | Rec: -2074554.00 | Epsilon: 0.475 | Vaciado: 3905s
#   Ep 103 | Rec: -1969029.00 | Epsilon: 0.475 | Vaciado: 4140s
#   Ep 104 | Rec: -1906474.00 | Epsilon: 0.475 | Vaciado: 3780s
#   Ep 105 | Rec: -2267030.00 | Epsilon: 0.474 | Vaciado: 4090s
#   Ep 106 | Rec: -1851414.00 | Epsilon: 0.474 | Vaciado: 3975s
#   Ep 107 | Rec: -2255972.00 | Epsilon: 0.474 | Vaciado: 3910s
#   Ep 108 | Rec: -1939377.00 | Epsilon: 0.474 | Vaciado: 3990s
#   Ep 109 | Rec: -1830855.00 | Epsilon: 0.473 | Vaciado: 3765s
#   Ep 110 | Rec: -2397778.00 | Epsilon: 0.473 | Vaciado: 4355s
#   Ep 111 | Rec: -2102780.00 | Epsilon: 0.473 | Vaciado: 3970s
#   Ep 112 | Rec: -2040196.00 | Epsilon: 0.473 | Vaciado: 3835s
#   Ep 113 | Rec: -1730577.00 | Epsilon: 0.473 | Vaciado: 3865s
#   Ep 114 | Rec: -2085700.00 | Epsilon: 0.472 | Vaciado: 3775s
#   Ep 115 | Rec: -2054668.00 | Epsilon: 0.472 | Vaciado: 4140s
#   Ep 116 | Rec: -1848249.00 | Epsilon: 0.472 | Vaciado: 3820s
#   Ep 117 | Rec: -2061039.00 | Epsilon: 0.472 | Vaciado: 3955s
#   Ep 118 | Rec: -1804824.00 | Epsilon: 0.471 | Vaciado: 3970s
#   Ep 119 | Rec: -2701476.00 | Epsilon: 0.471 | Vaciado: 4265s
#   Ep 120 | Rec: -1988924.00 | Epsilon: 0.471 | Vaciado: 3785s
#   Ep 121 | Rec: -1913114.00 | Epsilon: 0.471 | Vaciado: 3825s
#   Ep 122 | Rec: -2128085.00 | Epsilon: 0.470 | Vaciado: 3900s
#   Ep 123 | Rec: -2575063.00 | Epsilon: 0.470 | Vaciado: 4020s
#   Ep 124 | Rec: -2221489.00 | Epsilon: 0.470 | Vaciado: 4010s
#   Ep 125 | Rec: -1833577.00 | Epsilon: 0.470 | Vaciado: 3860s
#   Ep 126 | Rec: -1934809.00 | Epsilon: 0.469 | Vaciado: 3890s
#   Ep 127 | Rec: -2053233.00 | Epsilon: 0.469 | Vaciado: 3840s
#   Ep 128 | Rec: -2194790.00 | Epsilon: 0.469 | Vaciado: 4150s
#   Ep 129 | Rec: -2345714.00 | Epsilon: 0.469 | Vaciado: 4165s
#   Ep 130 | Rec: -2275984.00 | Epsilon: 0.469 | Vaciado: 3875s
#   Ep 131 | Rec: -2135153.00 | Epsilon: 0.468 | Vaciado: 3765s
#   Ep 132 | Rec: -2110145.00 | Epsilon: 0.468 | Vaciado: 3870s
#   Ep 133 | Rec: -2014447.00 | Epsilon: 0.468 | Vaciado: 3785s
#   Ep 134 | Rec: -2147525.00 | Epsilon: 0.468 | Vaciado: 3895s
#   Ep 135 | Rec: -1757386.00 | Epsilon: 0.467 | Vaciado: 3895s
#   Ep 136 | Rec: -2660020.00 | Epsilon: 0.467 | Vaciado: 4345s
#   Ep 137 | Rec: -2163801.00 | Epsilon: 0.467 | Vaciado: 3985s
#   Ep 138 | Rec: -2045194.00 | Epsilon: 0.467 | Vaciado: 3820s
#   Ep 139 | Rec: -1854671.00 | Epsilon: 0.466 | Vaciado: 3730s
#   Ep 140 | Rec: -2315338.00 | Epsilon: 0.466 | Vaciado: 4280s
#   Ep 141 | Rec: -2071972.00 | Epsilon: 0.466 | Vaciado: 3845s
#   Ep 142 | Rec: -1943820.00 | Epsilon: 0.466 | Vaciado: 3765s
#   Ep 143 | Rec: -2359305.00 | Epsilon: 0.465 | Vaciado: 3930s
#   Ep 144 | Rec: -2000832.00 | Epsilon: 0.465 | Vaciado: 3820s
#   Ep 145 | Rec: -1949993.00 | Epsilon: 0.465 | Vaciado: 3830s
#   Ep 146 | Rec: -2140736.00 | Epsilon: 0.465 | Vaciado: 3805s
#   Ep 147 | Rec: -1993505.00 | Epsilon: 0.465 | Vaciado: 3910s
#   Ep 148 | Rec: -2164408.00 | Epsilon: 0.464 | Vaciado: 4095s
#   Ep 149 | Rec: -2033743.00 | Epsilon: 0.464 | Vaciado: 3805s
#   Ep 150 | Rec: -2199256.00 | Epsilon: 0.464 | Vaciado: 3995s
#   Ep 151 | Rec: -1748031.00 | Epsilon: 0.464 | Vaciado: 3955s
#   Ep 152 | Rec: -1963213.00 | Epsilon: 0.463 | Vaciado: 4075s
#   Ep 153 | Rec: -1880395.00 | Epsilon: 0.463 | Vaciado: 3815s
#   Ep 154 | Rec: -1954475.00 | Epsilon: 0.463 | Vaciado: 4035s
#   Ep 155 | Rec: -1972069.00 | Epsilon: 0.463 | Vaciado: 3965s
#   Ep 156 | Rec: -2185987.00 | Epsilon: 0.462 | Vaciado: 3935s
#   Ep 157 | Rec: -2239987.00 | Epsilon: 0.462 | Vaciado: 4190s
#   Ep 158 | Rec: -2103135.00 | Epsilon: 0.462 | Vaciado: 3905s
#   Ep 159 | Rec: -2398014.00 | Epsilon: 0.462 | Vaciado: 4020s
#   Ep 160 | Rec: -2414899.00 | Epsilon: 0.462 | Vaciado: 4030s
#   Ep 161 | Rec: -2096134.00 | Epsilon: 0.461 | Vaciado: 3920s
#   Ep 162 | Rec: -2063230.00 | Epsilon: 0.461 | Vaciado: 3845s
#   Ep 163 | Rec: -2306173.00 | Epsilon: 0.461 | Vaciado: 3770s
#   Ep 164 | Rec: -2106216.00 | Epsilon: 0.461 | Vaciado: 4095s
#   Ep 165 | Rec: -1783984.00 | Epsilon: 0.460 | Vaciado: 3925s
#   Ep 166 | Rec: -1998828.00 | Epsilon: 0.460 | Vaciado: 3845s
#   Ep 167 | Rec: -1803933.00 | Epsilon: 0.460 | Vaciado: 3805s
#   Ep 168 | Rec: -2017299.00 | Epsilon: 0.460 | Vaciado: 3945s
#   Ep 169 | Rec: -2067370.00 | Epsilon: 0.459 | Vaciado: 3975s
#   Ep 170 | Rec: -1968438.00 | Epsilon: 0.459 | Vaciado: 3815s
#   Ep 171 | Rec: -1904752.00 | Epsilon: 0.459 | Vaciado: 3780s
#   Ep 172 | Rec: -1783849.00 | Epsilon: 0.459 | Vaciado: 3800s
#   Ep 173 | Rec: -2020092.00 | Epsilon: 0.459 | Vaciado: 3820s
#   Ep 174 | Rec: -2074384.00 | Epsilon: 0.458 | Vaciado: 3980s
#   Ep 175 | Rec: -1862967.00 | Epsilon: 0.458 | Vaciado: 3945s
#   Ep 176 | Rec: -2279634.00 | Epsilon: 0.458 | Vaciado: 3700s
#   Ep 177 | Rec: -1797161.00 | Epsilon: 0.458 | Vaciado: 3875s
#   Ep 178 | Rec: -2430974.00 | Epsilon: 0.457 | Vaciado: 4190s
#   Ep 179 | Rec: -2235378.00 | Epsilon: 0.457 | Vaciado: 3895s
#   Ep 180 | Rec: -2206818.00 | Epsilon: 0.457 | Vaciado: 3940s
#   Ep 181 | Rec: -2013593.00 | Epsilon: 0.457 | Vaciado: 3785s
#   Ep 182 | Rec: -1908853.00 | Epsilon: 0.456 | Vaciado: 3830s
#   Ep 183 | Rec: -2057600.00 | Epsilon: 0.456 | Vaciado: 4205s
#   Ep 184 | Rec: -2048456.00 | Epsilon: 0.456 | Vaciado: 3905s
#   Ep 185 | Rec: -2078789.00 | Epsilon: 0.456 | Vaciado: 3910s
#   Ep 186 | Rec: -2054051.00 | Epsilon: 0.456 | Vaciado: 4075s
#   Ep 187 | Rec: -2293550.00 | Epsilon: 0.455 | Vaciado: 3730s
#   Ep 188 | Rec: -2196795.00 | Epsilon: 0.455 | Vaciado: 4115s
#   Ep 189 | Rec: -1974115.00 | Epsilon: 0.455 | Vaciado: 3785s
#   Ep 190 | Rec: -2604463.00 | Epsilon: 0.455 | Vaciado: 3960s
#   Ep 191 | Rec: -2266150.00 | Epsilon: 0.454 | Vaciado: 3910s
#   Ep 192 | Rec: -1947536.00 | Epsilon: 0.454 | Vaciado: 3790s
#   Ep 193 | Rec: -1817382.00 | Epsilon: 0.454 | Vaciado: 3840s
#   Ep 194 | Rec: -2143499.00 | Epsilon: 0.454 | Vaciado: 3835s
#   Ep 195 | Rec: -1919166.00 | Epsilon: 0.454 | Vaciado: 4065s
#   Ep 196 | Rec: -2320919.00 | Epsilon: 0.453 | Vaciado: 4415s
#   Ep 197 | Rec: -2469068.00 | Epsilon: 0.453 | Vaciado: 4235s
#   Ep 198 | Rec: -1955731.00 | Epsilon: 0.453 | Vaciado: 3835s
#   Ep 199 | Rec: -2339659.00 | Epsilon: 0.453 | Vaciado: 3795s
#   Ep 200 | Rec: -2099312.00 | Epsilon: 0.452 | Vaciado: 3875s | Cobertura: 52.5%
#   Ep 201 | Rec: -2170091.00 | Epsilon: 0.452 | Vaciado: 3960s
#   Ep 202 | Rec: -1983269.00 | Epsilon: 0.452 | Vaciado: 3780s
#   Ep 203 | Rec: -1957248.00 | Epsilon: 0.452 | Vaciado: 3770s
#   Ep 204 | Rec: -2332261.00 | Epsilon: 0.452 | Vaciado: 4145s
#   Ep 205 | Rec: -2144856.00 | Epsilon: 0.451 | Vaciado: 3940s
#   Ep 206 | Rec: -2094888.00 | Epsilon: 0.451 | Vaciado: 3855s
#   Ep 207 | Rec: -1782721.00 | Epsilon: 0.451 | Vaciado: 3920s
#   Ep 208 | Rec: -2454723.00 | Epsilon: 0.451 | Vaciado: 4090s
#   Ep 209 | Rec: -2175693.00 | Epsilon: 0.450 | Vaciado: 3875s
#   Ep 210 | Rec: -2188022.00 | Epsilon: 0.450 | Vaciado: 4095s
#   Ep 211 | Rec: -1864825.00 | Epsilon: 0.450 | Vaciado: 3930s
#   Ep 212 | Rec: -2378214.00 | Epsilon: 0.450 | Vaciado: 4340s
#   Ep 213 | Rec: -2310111.00 | Epsilon: 0.449 | Vaciado: 3890s
#   Ep 214 | Rec: -2032553.00 | Epsilon: 0.449 | Vaciado: 3895s
#   Ep 215 | Rec: -1918452.00 | Epsilon: 0.449 | Vaciado: 4090s
#   Ep 216 | Rec: -2449820.00 | Epsilon: 0.449 | Vaciado: 3990s
#   Ep 217 | Rec: -2226859.00 | Epsilon: 0.449 | Vaciado: 3785s
#   Ep 218 | Rec: -1908769.00 | Epsilon: 0.448 | Vaciado: 3855s
#   Ep 219 | Rec: -2123863.00 | Epsilon: 0.448 | Vaciado: 3870s
#   Ep 220 | Rec: -1779042.00 | Epsilon: 0.448 | Vaciado: 3985s
#   Ep 221 | Rec: -2356596.00 | Epsilon: 0.448 | Vaciado: 3845s
#   Ep 222 | Rec: -2330913.00 | Epsilon: 0.447 | Vaciado: 4025s
#   Ep 223 | Rec: -2109351.00 | Epsilon: 0.447 | Vaciado: 3780s
#   Ep 224 | Rec: -2015075.00 | Epsilon: 0.447 | Vaciado: 3765s
#   Ep 225 | Rec: -2117547.00 | Epsilon: 0.447 | Vaciado: 3840s
#   Ep 226 | Rec: -1989703.00 | Epsilon: 0.447 | Vaciado: 3740s
#   Ep 227 | Rec: -2060620.00 | Epsilon: 0.446 | Vaciado: 3755s
#   Ep 228 | Rec: -2231516.00 | Epsilon: 0.446 | Vaciado: 3855s
#   Ep 229 | Rec: -2138946.00 | Epsilon: 0.446 | Vaciado: 3820s
#   Ep 230 | Rec: -2047601.00 | Epsilon: 0.446 | Vaciado: 4035s
#   Ep 231 | Rec: -1807555.00 | Epsilon: 0.445 | Vaciado: 4190s
#   Ep 232 | Rec: -1989097.00 | Epsilon: 0.445 | Vaciado: 3830s
#   Ep 233 | Rec: -2412402.00 | Epsilon: 0.445 | Vaciado: 4060s
#   Ep 234 | Rec: -2004118.00 | Epsilon: 0.445 | Vaciado: 3840s
#   Ep 235 | Rec: -1973821.00 | Epsilon: 0.445 | Vaciado: 3790s
#   Ep 236 | Rec: -2438105.00 | Epsilon: 0.444 | Vaciado: 3860s
#   Ep 237 | Rec: -2067581.00 | Epsilon: 0.444 | Vaciado: 3815s
#   Ep 238 | Rec: -2266670.00 | Epsilon: 0.444 | Vaciado: 4040s
#   Ep 239 | Rec: -2021597.00 | Epsilon: 0.444 | Vaciado: 3950s
#   Ep 240 | Rec: -1780257.00 | Epsilon: 0.443 | Vaciado: 3770s
#   Ep 241 | Rec: -1867442.00 | Epsilon: 0.443 | Vaciado: 3785s
#   Ep 242 | Rec: -2090809.00 | Epsilon: 0.443 | Vaciado: 4070s
#   Ep 243 | Rec: -2133039.00 | Epsilon: 0.443 | Vaciado: 3835s
#   Ep 244 | Rec: -1942748.00 | Epsilon: 0.443 | Vaciado: 3970s
#   Ep 245 | Rec: -2008552.00 | Epsilon: 0.442 | Vaciado: 3880s
#   Ep 246 | Rec: -1953410.00 | Epsilon: 0.442 | Vaciado: 3820s
#   Ep 247 | Rec: -2411831.00 | Epsilon: 0.442 | Vaciado: 3905s
#   Ep 248 | Rec: -1945888.00 | Epsilon: 0.442 | Vaciado: 3825s
#   Ep 249 | Rec: -2161080.00 | Epsilon: 0.441 | Vaciado: 3960s
#   Ep 250 | Rec: -1863105.00 | Epsilon: 0.441 | Vaciado: 3760s
#   Ep 251 | Rec: -2198467.00 | Epsilon: 0.441 | Vaciado: 4030s
#   Ep 252 | Rec: -2003458.00 | Epsilon: 0.441 | Vaciado: 3770s
#   Ep 253 | Rec: -1823976.00 | Epsilon: 0.441 | Vaciado: 3875s
#   Ep 254 | Rec: -2155877.00 | Epsilon: 0.440 | Vaciado: 3780s
#   Ep 255 | Rec: -1920732.00 | Epsilon: 0.440 | Vaciado: 3905s
#   Ep 256 | Rec: -2149429.00 | Epsilon: 0.440 | Vaciado: 4240s
#   Ep 257 | Rec: -2591797.00 | Epsilon: 0.440 | Vaciado: 4400s
#   Ep 258 | Rec: -2072477.00 | Epsilon: 0.439 | Vaciado: 4050s
#   Ep 259 | Rec: -2398322.00 | Epsilon: 0.439 | Vaciado: 4160s
#   Ep 260 | Rec: -2014945.00 | Epsilon: 0.439 | Vaciado: 3795s
#   Ep 261 | Rec: -2242828.00 | Epsilon: 0.439 | Vaciado: 3860s
#   Ep 262 | Rec: -2017950.00 | Epsilon: 0.439 | Vaciado: 3790s
#   Ep 263 | Rec: -1909938.00 | Epsilon: 0.438 | Vaciado: 3805s
#   Ep 264 | Rec: -1951067.00 | Epsilon: 0.438 | Vaciado: 4035s
#   Ep 265 | Rec: -1778631.00 | Epsilon: 0.438 | Vaciado: 3820s
#   Ep 266 | Rec: -2110025.00 | Epsilon: 0.438 | Vaciado: 4165s
#   Ep 267 | Rec: -1871331.00 | Epsilon: 0.437 | Vaciado: 3790s
#   Ep 268 | Rec: -1976656.00 | Epsilon: 0.437 | Vaciado: 3930s
#   Ep 269 | Rec: -1883458.00 | Epsilon: 0.437 | Vaciado: 4035s
#   Ep 270 | Rec: -2398672.00 | Epsilon: 0.437 | Vaciado: 4230s
#   Ep 271 | Rec: -1942997.00 | Epsilon: 0.437 | Vaciado: 3855s
#   Ep 272 | Rec: -1894816.00 | Epsilon: 0.436 | Vaciado: 3875s
#   Ep 273 | Rec: -2319257.00 | Epsilon: 0.436 | Vaciado: 4060s
#   Ep 274 | Rec: -1749622.00 | Epsilon: 0.436 | Vaciado: 3820s
#   Ep 275 | Rec: -2277906.00 | Epsilon: 0.436 | Vaciado: 4145s
#   Ep 276 | Rec: -2364502.00 | Epsilon: 0.436 | Vaciado: 3985s
#   Ep 277 | Rec: -1995548.00 | Epsilon: 0.435 | Vaciado: 3820s
#   Ep 278 | Rec: -1865442.00 | Epsilon: 0.435 | Vaciado: 3855s
#   Ep 279 | Rec: -2090462.00 | Epsilon: 0.435 | Vaciado: 3880s
#   Ep 280 | Rec: -2250777.00 | Epsilon: 0.435 | Vaciado: 3955s
#   Ep 281 | Rec: -2288971.00 | Epsilon: 0.434 | Vaciado: 4005s
#   Ep 282 | Rec: -1838375.00 | Epsilon: 0.434 | Vaciado: 4025s
#   Ep 283 | Rec: -2035948.00 | Epsilon: 0.434 | Vaciado: 3990s
#   Ep 284 | Rec: -2123429.00 | Epsilon: 0.434 | Vaciado: 3885s
#   Ep 285 | Rec: -2179609.00 | Epsilon: 0.434 | Vaciado: 4060s
#   Ep 286 | Rec: -2084943.00 | Epsilon: 0.433 | Vaciado: 3890s
#   Ep 287 | Rec: -2089878.00 | Epsilon: 0.433 | Vaciado: 3815s
#   Ep 288 | Rec: -1871675.00 | Epsilon: 0.433 | Vaciado: 3765s
#   Ep 289 | Rec: -2031276.00 | Epsilon: 0.433 | Vaciado: 3885s
#   Ep 290 | Rec: -2146760.00 | Epsilon: 0.432 | Vaciado: 3760s
#   Ep 291 | Rec: -2046161.00 | Epsilon: 0.432 | Vaciado: 4085s
#   Ep 292 | Rec: -1658940.00 | Epsilon: 0.432 | Vaciado: 3925s
#   Ep 293 | Rec: -1990108.00 | Epsilon: 0.432 | Vaciado: 3905s
#   Ep 294 | Rec: -2264564.00 | Epsilon: 0.432 | Vaciado: 3920s
#   Ep 295 | Rec: -1887147.00 | Epsilon: 0.431 | Vaciado: 3890s
#   Ep 296 | Rec: -2250148.00 | Epsilon: 0.431 | Vaciado: 3860s
#   Ep 297 | Rec: -2250688.00 | Epsilon: 0.431 | Vaciado: 4035s
#   Ep 298 | Rec: -2250063.00 | Epsilon: 0.431 | Vaciado: 4115s
#   Ep 299 | Rec: -2127000.00 | Epsilon: 0.431 | Vaciado: 3810s
#   Ep 300 | Rec: -2185629.00 | Epsilon: 0.430 | Vaciado: 3790s | Cobertura: 53.7%
#   Ep 301 | Rec: -2046219.00 | Epsilon: 0.430 | Vaciado: 3820s
#   Ep 302 | Rec: -2105854.00 | Epsilon: 0.430 | Vaciado: 4000s
#   Ep 303 | Rec: -1889963.00 | Epsilon: 0.430 | Vaciado: 3770s
#   Ep 304 | Rec: -1978629.00 | Epsilon: 0.429 | Vaciado: 3925s
#   Ep 305 | Rec: -2376295.00 | Epsilon: 0.429 | Vaciado: 3920s
#   Ep 306 | Rec: -1881801.00 | Epsilon: 0.429 | Vaciado: 3880s
#   Ep 307 | Rec: -1941880.00 | Epsilon: 0.429 | Vaciado: 3785s
#   Ep 308 | Rec: -2009403.00 | Epsilon: 0.429 | Vaciado: 3780s
#   Ep 309 | Rec: -2015345.00 | Epsilon: 0.428 | Vaciado: 3935s
#   Ep 310 | Rec: -2360664.00 | Epsilon: 0.428 | Vaciado: 3815s
#   Ep 311 | Rec: -2046606.00 | Epsilon: 0.428 | Vaciado: 3935s
#   Ep 312 | Rec: -2090231.00 | Epsilon: 0.428 | Vaciado: 3975s
#   Ep 313 | Rec: -2252536.00 | Epsilon: 0.428 | Vaciado: 3945s
#   Ep 314 | Rec: -1940072.00 | Epsilon: 0.427 | Vaciado: 3810s
#   Ep 315 | Rec: -2656197.00 | Epsilon: 0.427 | Vaciado: 3790s
#   Ep 316 | Rec: -2139828.00 | Epsilon: 0.427 | Vaciado: 4085s
#   Ep 317 | Rec: -2027926.00 | Epsilon: 0.427 | Vaciado: 3955s
#   Ep 318 | Rec: -1898767.00 | Epsilon: 0.426 | Vaciado: 3775s
#   Ep 319 | Rec: -1960775.00 | Epsilon: 0.426 | Vaciado: 3785s
#   Ep 320 | Rec: -2007688.00 | Epsilon: 0.426 | Vaciado: 3760s
#   Ep 321 | Rec: -2425092.00 | Epsilon: 0.426 | Vaciado: 4265s
#   Ep 322 | Rec: -2530236.00 | Epsilon: 0.426 | Vaciado: 4290s
#   Ep 323 | Rec: -2161051.00 | Epsilon: 0.425 | Vaciado: 4135s
#   Ep 324 | Rec: -1870586.00 | Epsilon: 0.425 | Vaciado: 3795s
#   Ep 325 | Rec: -1946219.00 | Epsilon: 0.425 | Vaciado: 3935s
#   Ep 326 | Rec: -2047906.00 | Epsilon: 0.425 | Vaciado: 3780s
#   Ep 327 | Rec: -1954748.00 | Epsilon: 0.425 | Vaciado: 3905s
#   Ep 328 | Rec: -1950773.00 | Epsilon: 0.424 | Vaciado: 3915s
#   Ep 329 | Rec: -2124485.00 | Epsilon: 0.424 | Vaciado: 4255s
#   Ep 330 | Rec: -2016709.00 | Epsilon: 0.424 | Vaciado: 4175s
#   Ep 331 | Rec: -2209439.00 | Epsilon: 0.424 | Vaciado: 4285s
#   Ep 332 | Rec: -2185442.00 | Epsilon: 0.424 | Vaciado: 3825s
#   Ep 333 | Rec: -2294763.00 | Epsilon: 0.423 | Vaciado: 4030s
#   Ep 334 | Rec: -2442644.00 | Epsilon: 0.423 | Vaciado: 4260s
#   Ep 335 | Rec: -1908743.00 | Epsilon: 0.423 | Vaciado: 3755s
#   Ep 336 | Rec: -2370175.00 | Epsilon: 0.423 | Vaciado: 3980s
#   Ep 337 | Rec: -2391845.00 | Epsilon: 0.422 | Vaciado: 3865s
#   Ep 338 | Rec: -2070710.00 | Epsilon: 0.422 | Vaciado: 3895s
#   Ep 339 | Rec: -1985962.00 | Epsilon: 0.422 | Vaciado: 3935s
#   Ep 340 | Rec: -2121319.00 | Epsilon: 0.422 | Vaciado: 3995s
#   Ep 341 | Rec: -1750433.00 | Epsilon: 0.422 | Vaciado: 3830s
#   Ep 342 | Rec: -1850388.00 | Epsilon: 0.421 | Vaciado: 3885s
#   Ep 343 | Rec: -2045103.00 | Epsilon: 0.421 | Vaciado: 3825s
#   Ep 344 | Rec: -1879338.00 | Epsilon: 0.421 | Vaciado: 3745s
#   Ep 345 | Rec: -2138951.00 | Epsilon: 0.421 | Vaciado: 3775s
#   Ep 346 | Rec: -2377435.00 | Epsilon: 0.421 | Vaciado: 4005s
#   Ep 347 | Rec: -2088397.00 | Epsilon: 0.420 | Vaciado: 3820s
#   Ep 348 | Rec: -1923668.00 | Epsilon: 0.420 | Vaciado: 3895s
#   Ep 349 | Rec: -2036502.00 | Epsilon: 0.420 | Vaciado: 3800s
#   Ep 350 | Rec: -2093502.00 | Epsilon: 0.420 | Vaciado: 3890s
#   Ep 351 | Rec: -2168719.00 | Epsilon: 0.420 | Vaciado: 3810s
#   Ep 352 | Rec: -2023156.00 | Epsilon: 0.419 | Vaciado: 3935s
#   Ep 353 | Rec: -2043739.00 | Epsilon: 0.419 | Vaciado: 3825s
#   Ep 354 | Rec: -2053169.00 | Epsilon: 0.419 | Vaciado: 3790s
#   Ep 355 | Rec: -2147989.00 | Epsilon: 0.419 | Vaciado: 3950s
#   Ep 356 | Rec: -1888221.00 | Epsilon: 0.418 | Vaciado: 3895s
#   Ep 357 | Rec: -2157118.00 | Epsilon: 0.418 | Vaciado: 3795s
#   Ep 358 | Rec: -2070021.00 | Epsilon: 0.418 | Vaciado: 3925s
#   Ep 359 | Rec: -2093989.00 | Epsilon: 0.418 | Vaciado: 3985s
#   Ep 360 | Rec: -2014392.00 | Epsilon: 0.418 | Vaciado: 3890s
#   Ep 361 | Rec: -1851887.00 | Epsilon: 0.417 | Vaciado: 3830s
#   Ep 362 | Rec: -2317929.00 | Epsilon: 0.417 | Vaciado: 3940s
#   Ep 363 | Rec: -2512233.00 | Epsilon: 0.417 | Vaciado: 3910s
#   Ep 364 | Rec: -2143149.00 | Epsilon: 0.417 | Vaciado: 4000s
#   Ep 365 | Rec: -2029426.00 | Epsilon: 0.417 | Vaciado: 3815s
#   Ep 366 | Rec: -2234912.00 | Epsilon: 0.416 | Vaciado: 3895s
#   Ep 367 | Rec: -1972863.00 | Epsilon: 0.416 | Vaciado: 3890s
#   Ep 368 | Rec: -2264609.00 | Epsilon: 0.416 | Vaciado: 3790s
#   Ep 369 | Rec: -1863750.00 | Epsilon: 0.416 | Vaciado: 3790s
#   Ep 370 | Rec: -1897182.00 | Epsilon: 0.416 | Vaciado: 3780s
#   Ep 371 | Rec: -2147724.00 | Epsilon: 0.415 | Vaciado: 3975s
#   Ep 372 | Rec: -2043866.00 | Epsilon: 0.415 | Vaciado: 3770s
#   Ep 373 | Rec: -2156877.00 | Epsilon: 0.415 | Vaciado: 3980s
#   Ep 374 | Rec: -2059895.00 | Epsilon: 0.415 | Vaciado: 3800s
#   Ep 375 | Rec: -1977383.00 | Epsilon: 0.414 | Vaciado: 3905s
#   Ep 376 | Rec: -2306075.00 | Epsilon: 0.414 | Vaciado: 3905s
#   Ep 377 | Rec: -1758739.00 | Epsilon: 0.414 | Vaciado: 3810s
#   Ep 378 | Rec: -1895881.00 | Epsilon: 0.414 | Vaciado: 3925s
#   Ep 379 | Rec: -2220058.00 | Epsilon: 0.414 | Vaciado: 4085s
#   Ep 380 | Rec: -2057130.00 | Epsilon: 0.413 | Vaciado: 3845s
#   Ep 381 | Rec: -2463800.00 | Epsilon: 0.413 | Vaciado: 4000s
#   Ep 382 | Rec: -2459925.00 | Epsilon: 0.413 | Vaciado: 4240s
#   Ep 383 | Rec: -2177495.00 | Epsilon: 0.413 | Vaciado: 4025s
#   Ep 384 | Rec: -1884957.00 | Epsilon: 0.413 | Vaciado: 3850s
#   Ep 385 | Rec: -1695149.00 | Epsilon: 0.412 | Vaciado: 3810s
#   Ep 386 | Rec: -2052111.00 | Epsilon: 0.412 | Vaciado: 3880s
#   Ep 387 | Rec: -1851425.00 | Epsilon: 0.412 | Vaciado: 3840s
#   Ep 388 | Rec: -1851512.00 | Epsilon: 0.412 | Vaciado: 4030s
#   Ep 389 | Rec: -1771151.00 | Epsilon: 0.412 | Vaciado: 3795s
#   Ep 390 | Rec: -1833824.00 | Epsilon: 0.411 | Vaciado: 4030s
#   Ep 391 | Rec: -2042560.00 | Epsilon: 0.411 | Vaciado: 4185s
#   Ep 392 | Rec: -2056122.00 | Epsilon: 0.411 | Vaciado: 3720s
#   Ep 393 | Rec: -2274468.00 | Epsilon: 0.411 | Vaciado: 3815s
#   Ep 394 | Rec: -2086291.00 | Epsilon: 0.411 | Vaciado: 4085s
#   Ep 395 | Rec: -1971299.00 | Epsilon: 0.410 | Vaciado: 3825s
#   Ep 396 | Rec: -2344738.00 | Epsilon: 0.410 | Vaciado: 4200s
#   Ep 397 | Rec: -2219106.00 | Epsilon: 0.410 | Vaciado: 4250s
#   Ep 398 | Rec: -1953202.00 | Epsilon: 0.410 | Vaciado: 4040s
#   Ep 399 | Rec: -2427200.00 | Epsilon: 0.410 | Vaciado: 4375s
#   Ep 400 | Rec: -1737595.00 | Epsilon: 0.409 | Vaciado: 3800s | Cobertura: 54.6%
#   Ep 401 | Rec: -2308864.00 | Epsilon: 0.409 | Vaciado: 3955s
#   Ep 402 | Rec: -2426802.00 | Epsilon: 0.409 | Vaciado: 3925s
#   Ep 403 | Rec: -2046265.00 | Epsilon: 0.409 | Vaciado: 3900s
#   Ep 404 | Rec: -2285778.00 | Epsilon: 0.409 | Vaciado: 4130s
#   Ep 405 | Rec: -1865154.00 | Epsilon: 0.408 | Vaciado: 3845s
#   Ep 406 | Rec: -1852162.00 | Epsilon: 0.408 | Vaciado: 4000s
#   Ep 407 | Rec: -1905951.00 | Epsilon: 0.408 | Vaciado: 3825s
#   Ep 408 | Rec: -2094181.00 | Epsilon: 0.408 | Vaciado: 4050s
#   Ep 409 | Rec: -2128082.00 | Epsilon: 0.408 | Vaciado: 3820s
#   Ep 410 | Rec: -2272644.00 | Epsilon: 0.407 | Vaciado: 4050s
#   Ep 411 | Rec: -1997842.00 | Epsilon: 0.407 | Vaciado: 3810s
#   Ep 412 | Rec: -1920438.00 | Epsilon: 0.407 | Vaciado: 3870s
#   Ep 413 | Rec: -2521088.00 | Epsilon: 0.407 | Vaciado: 4040s
#   Ep 414 | Rec: -2290051.00 | Epsilon: 0.406 | Vaciado: 4315s
#   Ep 415 | Rec: -1917250.00 | Epsilon: 0.406 | Vaciado: 3810s
#   Ep 416 | Rec: -2221049.00 | Epsilon: 0.406 | Vaciado: 4015s
#   Ep 417 | Rec: -2190780.00 | Epsilon: 0.406 | Vaciado: 4105s
#   Ep 418 | Rec: -1903640.00 | Epsilon: 0.406 | Vaciado: 3865s
#   Ep 419 | Rec: -1621808.00 | Epsilon: 0.405 | Vaciado: 3770s
#   Ep 420 | Rec: -2422555.00 | Epsilon: 0.405 | Vaciado: 4195s
#   Ep 421 | Rec: -1876563.00 | Epsilon: 0.405 | Vaciado: 3985s
#   Ep 422 | Rec: -1962440.00 | Epsilon: 0.405 | Vaciado: 3825s
#   Ep 423 | Rec: -2092533.00 | Epsilon: 0.405 | Vaciado: 3830s
#   Ep 424 | Rec: -1954623.00 | Epsilon: 0.404 | Vaciado: 3915s
#   Ep 425 | Rec: -2077373.00 | Epsilon: 0.404 | Vaciado: 3900s
#   Ep 426 | Rec: -1944721.00 | Epsilon: 0.404 | Vaciado: 4005s
#   Ep 427 | Rec: -2111470.00 | Epsilon: 0.404 | Vaciado: 3790s
#   Ep 428 | Rec: -2140180.00 | Epsilon: 0.404 | Vaciado: 4125s
#   Ep 429 | Rec: -2018103.00 | Epsilon: 0.403 | Vaciado: 4030s
#   Ep 430 | Rec: -1808015.00 | Epsilon: 0.403 | Vaciado: 4005s
#   Ep 431 | Rec: -1967011.00 | Epsilon: 0.403 | Vaciado: 4035s
#   Ep 432 | Rec: -2101468.00 | Epsilon: 0.403 | Vaciado: 4010s
#   Ep 433 | Rec: -2094040.00 | Epsilon: 0.403 | Vaciado: 3865s
#   Ep 434 | Rec: -1898869.00 | Epsilon: 0.402 | Vaciado: 3800s
#   Ep 435 | Rec: -2232066.00 | Epsilon: 0.402 | Vaciado: 3860s
#   Ep 436 | Rec: -2227086.00 | Epsilon: 0.402 | Vaciado: 3840s
#   Ep 437 | Rec: -2021761.00 | Epsilon: 0.402 | Vaciado: 3755s
#   Ep 438 | Rec: -1984272.00 | Epsilon: 0.402 | Vaciado: 3920s
#   Ep 439 | Rec: -2241593.00 | Epsilon: 0.401 | Vaciado: 3995s
#   Ep 440 | Rec: -2482445.00 | Epsilon: 0.401 | Vaciado: 3890s
#   Ep 441 | Rec: -2115860.00 | Epsilon: 0.401 | Vaciado: 3990s
#   Ep 442 | Rec: -1904975.00 | Epsilon: 0.401 | Vaciado: 3750s
#   Ep 443 | Rec: -2136818.00 | Epsilon: 0.401 | Vaciado: 3840s
#   Ep 444 | Rec: -2129519.00 | Epsilon: 0.400 | Vaciado: 4040s
#   Ep 445 | Rec: -1992191.00 | Epsilon: 0.400 | Vaciado: 3810s
#   Ep 446 | Rec: -1794219.00 | Epsilon: 0.400 | Vaciado: 3915s
#   Ep 447 | Rec: -1993719.00 | Epsilon: 0.400 | Vaciado: 3835s
#   Ep 448 | Rec: -2212238.00 | Epsilon: 0.400 | Vaciado: 4315s
#   Ep 449 | Rec: -2323567.00 | Epsilon: 0.399 | Vaciado: 4215s
#   Ep 450 | Rec: -1998387.00 | Epsilon: 0.399 | Vaciado: 3815s
#   Ep 451 | Rec: -2275484.00 | Epsilon: 0.399 | Vaciado: 3935s
#   Ep 452 | Rec: -2023635.00 | Epsilon: 0.399 | Vaciado: 3800s
#   Ep 453 | Rec: -2049074.00 | Epsilon: 0.399 | Vaciado: 4045s
#   Ep 454 | Rec: -2027548.00 | Epsilon: 0.398 | Vaciado: 3735s
#   Ep 455 | Rec: -2231579.00 | Epsilon: 0.398 | Vaciado: 4000s
#   Ep 456 | Rec: -2435299.00 | Epsilon: 0.398 | Vaciado: 4040s
#   Ep 457 | Rec: -1966977.00 | Epsilon: 0.398 | Vaciado: 3945s
#   Ep 458 | Rec: -2296443.00 | Epsilon: 0.398 | Vaciado: 3805s
#   Ep 459 | Rec: -2088854.00 | Epsilon: 0.397 | Vaciado: 3835s
#   Ep 460 | Rec: -2089028.00 | Epsilon: 0.397 | Vaciado: 4050s
#   Ep 461 | Rec: -1994460.00 | Epsilon: 0.397 | Vaciado: 3975s
#   Ep 462 | Rec: -2016096.00 | Epsilon: 0.397 | Vaciado: 4225s
#   Ep 463 | Rec: -2408065.00 | Epsilon: 0.397 | Vaciado: 3810s
#   Ep 464 | Rec: -1939359.00 | Epsilon: 0.396 | Vaciado: 3900s
#   Ep 465 | Rec: -2330462.00 | Epsilon: 0.396 | Vaciado: 4055s
#   Ep 466 | Rec: -1769251.00 | Epsilon: 0.396 | Vaciado: 3810s
#   Ep 467 | Rec: -2250692.00 | Epsilon: 0.396 | Vaciado: 4205s
#   Ep 468 | Rec: -1833357.00 | Epsilon: 0.396 | Vaciado: 3850s
#   Ep 469 | Rec: -1859450.00 | Epsilon: 0.395 | Vaciado: 3765s
#   Ep 470 | Rec: -2024918.00 | Epsilon: 0.395 | Vaciado: 3730s
#   Ep 471 | Rec: -2135677.00 | Epsilon: 0.395 | Vaciado: 3770s
#   Ep 472 | Rec: -1932737.00 | Epsilon: 0.395 | Vaciado: 3885s
#   Ep 473 | Rec: -2287846.00 | Epsilon: 0.395 | Vaciado: 4220s
#   Ep 474 | Rec: -2581594.00 | Epsilon: 0.394 | Vaciado: 4365s
#   Ep 475 | Rec: -1982088.00 | Epsilon: 0.394 | Vaciado: 3810s
#   Ep 476 | Rec: -2086909.00 | Epsilon: 0.394 | Vaciado: 3895s
#   Ep 477 | Rec: -2148403.00 | Epsilon: 0.394 | Vaciado: 3925s
#   Ep 478 | Rec: -1960693.00 | Epsilon: 0.394 | Vaciado: 3745s
#   Ep 479 | Rec: -2074429.00 | Epsilon: 0.393 | Vaciado: 4170s
#   Ep 480 | Rec: -2091765.00 | Epsilon: 0.393 | Vaciado: 4170s
#   Ep 481 | Rec: -2110676.00 | Epsilon: 0.393 | Vaciado: 3750s
#   Ep 482 | Rec: -2118350.00 | Epsilon: 0.393 | Vaciado: 3960s
#   Ep 483 | Rec: -2440130.00 | Epsilon: 0.393 | Vaciado: 4380s
#   Ep 484 | Rec: -2400640.00 | Epsilon: 0.393 | Vaciado: 4080s
#   Ep 485 | Rec: -2287924.00 | Epsilon: 0.392 | Vaciado: 4130s
#   Ep 486 | Rec: -2168898.00 | Epsilon: 0.392 | Vaciado: 3895s
#   Ep 487 | Rec: -1706389.00 | Epsilon: 0.392 | Vaciado: 3840s
#   Ep 488 | Rec: -2116138.00 | Epsilon: 0.392 | Vaciado: 3830s
#   Ep 489 | Rec: -2007647.00 | Epsilon: 0.392 | Vaciado: 3795s
#   Ep 490 | Rec: -2122942.00 | Epsilon: 0.391 | Vaciado: 3835s
#   Ep 491 | Rec: -1864018.00 | Epsilon: 0.391 | Vaciado: 3860s
#   Ep 492 | Rec: -1961631.00 | Epsilon: 0.391 | Vaciado: 3940s
#   Ep 493 | Rec: -2120488.00 | Epsilon: 0.391 | Vaciado: 4240s
#   Ep 494 | Rec: -2052812.00 | Epsilon: 0.391 | Vaciado: 3870s
#   Ep 495 | Rec: -1915652.00 | Epsilon: 0.390 | Vaciado: 3885s
#   Ep 496 | Rec: -2287737.00 | Epsilon: 0.390 | Vaciado: 3910s
#   Ep 497 | Rec: -2077707.00 | Epsilon: 0.390 | Vaciado: 3845s
#   Ep 498 | Rec: -1981238.00 | Epsilon: 0.390 | Vaciado: 3835s
#   Ep 499 | Rec: -2396592.00 | Epsilon: 0.390 | Vaciado: 3895s
#   Ep 500 | Rec: -2457339.00 | Epsilon: 0.389 | Vaciado: 3875s | Cobertura: 55.1%
#   Ep 501 | Rec: -1829217.00 | Epsilon: 0.389 | Vaciado: 3855s
#   Ep 502 | Rec: -1885064.00 | Epsilon: 0.389 | Vaciado: 3810s
#   Ep 503 | Rec: -2043787.00 | Epsilon: 0.389 | Vaciado: 4315s
#   Ep 504 | Rec: -2670317.00 | Epsilon: 0.389 | Vaciado: 4260s
#   Ep 505 | Rec: -1875620.00 | Epsilon: 0.388 | Vaciado: 3875s
#   Ep 506 | Rec: -2005250.00 | Epsilon: 0.388 | Vaciado: 3915s
#   Ep 507 | Rec: -2248846.00 | Epsilon: 0.388 | Vaciado: 4150s
#   Ep 508 | Rec: -2193150.00 | Epsilon: 0.388 | Vaciado: 3970s
#   Ep 509 | Rec: -2064882.00 | Epsilon: 0.388 | Vaciado: 4040s
#   Ep 510 | Rec: -2098684.00 | Epsilon: 0.387 | Vaciado: 3900s
#   Ep 511 | Rec: -1850901.00 | Epsilon: 0.387 | Vaciado: 3795s
#   Ep 512 | Rec: -2560838.00 | Epsilon: 0.387 | Vaciado: 4575s
#   Ep 513 | Rec: -1795082.00 | Epsilon: 0.387 | Vaciado: 4155s
#   Ep 514 | Rec: -2195986.00 | Epsilon: 0.387 | Vaciado: 3865s
#   Ep 515 | Rec: -2264268.00 | Epsilon: 0.386 | Vaciado: 3925s
#   Ep 516 | Rec: -2066152.00 | Epsilon: 0.386 | Vaciado: 3845s
#   Ep 517 | Rec: -2227468.00 | Epsilon: 0.386 | Vaciado: 3785s
#   Ep 518 | Rec: -2205992.00 | Epsilon: 0.386 | Vaciado: 4025s
#   Ep 519 | Rec: -1991936.00 | Epsilon: 0.386 | Vaciado: 3840s
#   Ep 520 | Rec: -2177619.00 | Epsilon: 0.386 | Vaciado: 3865s
#   Ep 521 | Rec: -2370316.00 | Epsilon: 0.385 | Vaciado: 3775s
#   Ep 522 | Rec: -2191582.00 | Epsilon: 0.385 | Vaciado: 3830s
#   Ep 523 | Rec: -2025510.00 | Epsilon: 0.385 | Vaciado: 3845s
#   Ep 524 | Rec: -2021885.00 | Epsilon: 0.385 | Vaciado: 3815s
#   Ep 525 | Rec: -2139338.00 | Epsilon: 0.385 | Vaciado: 3925s
#   Ep 526 | Rec: -1948196.00 | Epsilon: 0.384 | Vaciado: 3835s
#   Ep 527 | Rec: -2273500.00 | Epsilon: 0.384 | Vaciado: 3900s
#   Ep 528 | Rec: -2074045.00 | Epsilon: 0.384 | Vaciado: 3970s
#   Ep 529 | Rec: -2459365.00 | Epsilon: 0.384 | Vaciado: 3975s
#   Ep 530 | Rec: -2456549.00 | Epsilon: 0.384 | Vaciado: 3850s
#   Ep 531 | Rec: -2717523.00 | Epsilon: 0.383 | Vaciado: 4215s
#   Ep 532 | Rec: -2144195.00 | Epsilon: 0.383 | Vaciado: 3960s
#   Ep 533 | Rec: -2296382.00 | Epsilon: 0.383 | Vaciado: 3820s
#   Ep 534 | Rec: -2294535.00 | Epsilon: 0.383 | Vaciado: 4200s
#   Ep 535 | Rec: -2379063.00 | Epsilon: 0.383 | Vaciado: 4045s
#   Ep 536 | Rec: -1896171.00 | Epsilon: 0.382 | Vaciado: 3835s
#   Ep 537 | Rec: -1814824.00 | Epsilon: 0.382 | Vaciado: 3935s
#   Ep 538 | Rec: -1968423.00 | Epsilon: 0.382 | Vaciado: 3720s
#   Ep 539 | Rec: -2147742.00 | Epsilon: 0.382 | Vaciado: 4110s
#   Ep 540 | Rec: -2122443.00 | Epsilon: 0.382 | Vaciado: 4005s
#   Ep 541 | Rec: -1891876.00 | Epsilon: 0.381 | Vaciado: 3830s
#   Ep 542 | Rec: -2086131.00 | Epsilon: 0.381 | Vaciado: 3855s
#   Ep 543 | Rec: -1794896.00 | Epsilon: 0.381 | Vaciado: 3775s
#   Ep 544 | Rec: -1902075.00 | Epsilon: 0.381 | Vaciado: 3775s
#   Ep 545 | Rec: -2000774.00 | Epsilon: 0.381 | Vaciado: 3890s
#   Ep 546 | Rec: -2222665.00 | Epsilon: 0.381 | Vaciado: 3965s
#   Ep 547 | Rec: -2013265.00 | Epsilon: 0.380 | Vaciado: 3855s
#   Ep 548 | Rec: -2098353.00 | Epsilon: 0.380 | Vaciado: 4015s
#   Ep 549 | Rec: -2097213.00 | Epsilon: 0.380 | Vaciado: 3955s
#   Ep 550 | Rec: -2374450.00 | Epsilon: 0.380 | Vaciado: 4070s
#   Ep 551 | Rec: -2288040.00 | Epsilon: 0.380 | Vaciado: 3850s
#   Ep 552 | Rec: -1828243.00 | Epsilon: 0.379 | Vaciado: 3780s
#   Ep 553 | Rec: -2320844.00 | Epsilon: 0.379 | Vaciado: 3835s
#   Ep 554 | Rec: -2190864.00 | Epsilon: 0.379 | Vaciado: 3865s
#   Ep 555 | Rec: -2045154.00 | Epsilon: 0.379 | Vaciado: 3930s
#   Ep 556 | Rec: -1889667.00 | Epsilon: 0.379 | Vaciado: 3780s
#   Ep 557 | Rec: -2259227.00 | Epsilon: 0.378 | Vaciado: 4105s
#   Ep 558 | Rec: -2075984.00 | Epsilon: 0.378 | Vaciado: 3805s
#   Ep 559 | Rec: -1915292.00 | Epsilon: 0.378 | Vaciado: 3875s
#   Ep 560 | Rec: -1856101.00 | Epsilon: 0.378 | Vaciado: 3890s
#   Ep 561 | Rec: -2059575.00 | Epsilon: 0.378 | Vaciado: 3980s
#   Ep 562 | Rec: -1766723.00 | Epsilon: 0.377 | Vaciado: 3865s
#   Ep 563 | Rec: -2135383.00 | Epsilon: 0.377 | Vaciado: 3760s
#   Ep 564 | Rec: -2138389.00 | Epsilon: 0.377 | Vaciado: 4070s
#   Ep 565 | Rec: -2074758.00 | Epsilon: 0.377 | Vaciado: 3865s
#   Ep 566 | Rec: -1803219.00 | Epsilon: 0.377 | Vaciado: 3830s
#   Ep 567 | Rec: -2166856.00 | Epsilon: 0.377 | Vaciado: 4190s
#   Ep 568 | Rec: -1884987.00 | Epsilon: 0.376 | Vaciado: 3980s
#   Ep 569 | Rec: -1928788.00 | Epsilon: 0.376 | Vaciado: 4010s
#   Ep 570 | Rec: -2276466.00 | Epsilon: 0.376 | Vaciado: 3960s
#   Ep 571 | Rec: -2198224.00 | Epsilon: 0.376 | Vaciado: 3855s
#   Ep 572 | Rec: -1718897.00 | Epsilon: 0.376 | Vaciado: 4010s
#   Ep 573 | Rec: -2086457.00 | Epsilon: 0.375 | Vaciado: 3840s
#   Ep 574 | Rec: -1835855.00 | Epsilon: 0.375 | Vaciado: 3840s
#   Ep 575 | Rec: -2367035.00 | Epsilon: 0.375 | Vaciado: 4220s
#   Ep 576 | Rec: -2029101.00 | Epsilon: 0.375 | Vaciado: 4075s
#   Ep 577 | Rec: -2252922.00 | Epsilon: 0.375 | Vaciado: 3880s
#   Ep 578 | Rec: -1774327.00 | Epsilon: 0.374 | Vaciado: 3825s
#   Ep 579 | Rec: -2401108.00 | Epsilon: 0.374 | Vaciado: 4165s
#   Ep 580 | Rec: -2140777.00 | Epsilon: 0.374 | Vaciado: 3820s
#   Ep 581 | Rec: -1947746.00 | Epsilon: 0.374 | Vaciado: 3885s
#   Ep 582 | Rec: -2092757.00 | Epsilon: 0.374 | Vaciado: 3960s
#   Ep 583 | Rec: -2062991.00 | Epsilon: 0.374 | Vaciado: 3850s
#   Ep 584 | Rec: -1888983.00 | Epsilon: 0.373 | Vaciado: 3860s
#   Ep 585 | Rec: -2156744.00 | Epsilon: 0.373 | Vaciado: 3985s
#   Ep 586 | Rec: -1880804.00 | Epsilon: 0.373 | Vaciado: 3895s
#   Ep 587 | Rec: -2375856.00 | Epsilon: 0.373 | Vaciado: 3870s
#   Ep 588 | Rec: -1826385.00 | Epsilon: 0.373 | Vaciado: 3995s
#   Ep 589 | Rec: -2062163.00 | Epsilon: 0.372 | Vaciado: 3830s
#   Ep 590 | Rec: -1993673.00 | Epsilon: 0.372 | Vaciado: 3840s
#   Ep 591 | Rec: -2108159.00 | Epsilon: 0.372 | Vaciado: 3960s
#   Ep 592 | Rec: -1968743.00 | Epsilon: 0.372 | Vaciado: 3915s
#   Ep 593 | Rec: -2145168.00 | Epsilon: 0.372 | Vaciado: 3925s
#   Ep 594 | Rec: -2442133.00 | Epsilon: 0.371 | Vaciado: 4315s
#   Ep 595 | Rec: -2008952.00 | Epsilon: 0.371 | Vaciado: 3900s
#   Ep 596 | Rec: -2428488.00 | Epsilon: 0.371 | Vaciado: 4115s
#   Ep 597 | Rec: -2006005.00 | Epsilon: 0.371 | Vaciado: 3950s
#   Ep 598 | Rec: -2191974.00 | Epsilon: 0.371 | Vaciado: 3890s
#   Ep 599 | Rec: -2785620.00 | Epsilon: 0.371 | Vaciado: 4515s
#   Ep 600 | Rec: -2159550.00 | Epsilon: 0.370 | Vaciado: 3875s | Cobertura: 55.6%
#   Ep 601 | Rec: -2078603.00 | Epsilon: 0.370 | Vaciado: 3805s
#   Ep 602 | Rec: -2002722.00 | Epsilon: 0.370 | Vaciado: 3770s
#   Ep 603 | Rec: -1971360.00 | Epsilon: 0.370 | Vaciado: 3970s
#   Ep 604 | Rec: -1932399.00 | Epsilon: 0.370 | Vaciado: 4005s
#   Ep 605 | Rec: -2162312.00 | Epsilon: 0.369 | Vaciado: 3910s
#   Ep 606 | Rec: -2268629.00 | Epsilon: 0.369 | Vaciado: 3810s
#   Ep 607 | Rec: -2218377.00 | Epsilon: 0.369 | Vaciado: 3990s
#   Ep 608 | Rec: -1793079.00 | Epsilon: 0.369 | Vaciado: 3835s
#   Ep 609 | Rec: -1991249.00 | Epsilon: 0.369 | Vaciado: 3870s
#   Ep 610 | Rec: -1938694.00 | Epsilon: 0.369 | Vaciado: 4110s
#   Ep 611 | Rec: -2359486.00 | Epsilon: 0.368 | Vaciado: 4115s
#   Ep 612 | Rec: -2030924.00 | Epsilon: 0.368 | Vaciado: 4020s
#   Ep 613 | Rec: -2147993.00 | Epsilon: 0.368 | Vaciado: 4230s
#   Ep 614 | Rec: -1954240.00 | Epsilon: 0.368 | Vaciado: 3960s
#   Ep 615 | Rec: -2116179.00 | Epsilon: 0.368 | Vaciado: 3850s
#   Ep 616 | Rec: -2229142.00 | Epsilon: 0.367 | Vaciado: 4070s
#   Ep 617 | Rec: -2036438.00 | Epsilon: 0.367 | Vaciado: 3800s
#   Ep 618 | Rec: -2211093.00 | Epsilon: 0.367 | Vaciado: 4000s
#   Ep 619 | Rec: -2178858.00 | Epsilon: 0.367 | Vaciado: 3865s
#   Ep 620 | Rec: -1880098.00 | Epsilon: 0.367 | Vaciado: 3855s
#   Ep 621 | Rec: -1920495.00 | Epsilon: 0.367 | Vaciado: 3950s
#   Ep 622 | Rec: -2109220.00 | Epsilon: 0.366 | Vaciado: 3790s
#   Ep 623 | Rec: -2156986.00 | Epsilon: 0.366 | Vaciado: 4015s
#   Ep 624 | Rec: -2230253.00 | Epsilon: 0.366 | Vaciado: 4065s
#   Ep 625 | Rec: -2333578.00 | Epsilon: 0.366 | Vaciado: 3755s
#   Ep 626 | Rec: -2717212.00 | Epsilon: 0.366 | Vaciado: 4045s
#   Ep 627 | Rec: -2271447.00 | Epsilon: 0.365 | Vaciado: 3970s
#   Ep 628 | Rec: -1815020.00 | Epsilon: 0.365 | Vaciado: 3965s
#   Ep 629 | Rec: -1968951.00 | Epsilon: 0.365 | Vaciado: 4075s
#   Ep 630 | Rec: -2098409.00 | Epsilon: 0.365 | Vaciado: 3755s
#   Ep 631 | Rec: -2029961.00 | Epsilon: 0.365 | Vaciado: 3795s
#   Ep 632 | Rec: -1949304.00 | Epsilon: 0.365 | Vaciado: 3840s
#   Ep 633 | Rec: -1980806.00 | Epsilon: 0.364 | Vaciado: 3985s
#   Ep 634 | Rec: -2177286.00 | Epsilon: 0.364 | Vaciado: 4015s
#   Ep 635 | Rec: -1955734.00 | Epsilon: 0.364 | Vaciado: 3720s
#   Ep 636 | Rec: -2454034.00 | Epsilon: 0.364 | Vaciado: 4175s
#   Ep 637 | Rec: -1763185.00 | Epsilon: 0.364 | Vaciado: 3815s
#   Ep 638 | Rec: -2016507.00 | Epsilon: 0.363 | Vaciado: 3920s
#   Ep 639 | Rec: -2322109.00 | Epsilon: 0.363 | Vaciado: 3840s
#   Ep 640 | Rec: -1967069.00 | Epsilon: 0.363 | Vaciado: 3810s
#   Ep 641 | Rec: -1923469.00 | Epsilon: 0.363 | Vaciado: 3845s
#   Ep 642 | Rec: -1925313.00 | Epsilon: 0.363 | Vaciado: 3790s
#   Ep 643 | Rec: -1837804.00 | Epsilon: 0.363 | Vaciado: 3815s
#   Ep 644 | Rec: -2115034.00 | Epsilon: 0.362 | Vaciado: 3900s
#   Ep 645 | Rec: -1856312.00 | Epsilon: 0.362 | Vaciado: 3840s
#   Ep 646 | Rec: -2048826.00 | Epsilon: 0.362 | Vaciado: 4000s
#   Ep 647 | Rec: -2292568.00 | Epsilon: 0.362 | Vaciado: 4080s
#   Ep 648 | Rec: -1856867.00 | Epsilon: 0.362 | Vaciado: 3805s
#   Ep 649 | Rec: -2117644.00 | Epsilon: 0.361 | Vaciado: 4035s
#   Ep 650 | Rec: -2014725.00 | Epsilon: 0.361 | Vaciado: 3830s
#   Ep 651 | Rec: -2742312.00 | Epsilon: 0.361 | Vaciado: 4455s
#   Ep 652 | Rec: -2234331.00 | Epsilon: 0.361 | Vaciado: 3810s
#   Ep 653 | Rec: -2002702.00 | Epsilon: 0.361 | Vaciado: 3975s
#   Ep 654 | Rec: -2250746.00 | Epsilon: 0.361 | Vaciado: 4230s
#   Ep 655 | Rec: -2284736.00 | Epsilon: 0.360 | Vaciado: 3890s
#   Ep 656 | Rec: -2163890.00 | Epsilon: 0.360 | Vaciado: 4050s
#   Ep 657 | Rec: -2031388.00 | Epsilon: 0.360 | Vaciado: 3885s
#   Ep 658 | Rec: -2413893.00 | Epsilon: 0.360 | Vaciado: 3850s
#   Ep 659 | Rec: -1959296.00 | Epsilon: 0.360 | Vaciado: 4070s
#   Ep 660 | Rec: -2219735.00 | Epsilon: 0.359 | Vaciado: 3790s
#   Ep 661 | Rec: -2143899.00 | Epsilon: 0.359 | Vaciado: 3890s
#   Ep 662 | Rec: -1943462.00 | Epsilon: 0.359 | Vaciado: 3810s
#   Ep 663 | Rec: -2167868.00 | Epsilon: 0.359 | Vaciado: 3925s
#   Ep 664 | Rec: -1885785.00 | Epsilon: 0.359 | Vaciado: 3875s
#   Ep 665 | Rec: -2050862.00 | Epsilon: 0.359 | Vaciado: 3880s
#   Ep 666 | Rec: -1971229.00 | Epsilon: 0.358 | Vaciado: 3860s
#   Ep 667 | Rec: -2369894.00 | Epsilon: 0.358 | Vaciado: 3845s
#   Ep 668 | Rec: -1895493.00 | Epsilon: 0.358 | Vaciado: 3850s
#   Ep 669 | Rec: -1846308.00 | Epsilon: 0.358 | Vaciado: 3930s
#   Ep 670 | Rec: -2192395.00 | Epsilon: 0.358 | Vaciado: 4320s
#   Ep 671 | Rec: -2222041.00 | Epsilon: 0.357 | Vaciado: 4000s
#   Ep 672 | Rec: -1971105.00 | Epsilon: 0.357 | Vaciado: 3950s
#   Ep 673 | Rec: -2006945.00 | Epsilon: 0.357 | Vaciado: 3965s
#   Ep 674 | Rec: -2344325.00 | Epsilon: 0.357 | Vaciado: 3855s
#   Ep 675 | Rec: -1990961.00 | Epsilon: 0.357 | Vaciado: 4040s
#   Ep 676 | Rec: -1820723.00 | Epsilon: 0.357 | Vaciado: 4185s
#   Ep 677 | Rec: -1822976.00 | Epsilon: 0.356 | Vaciado: 3940s
#   Ep 678 | Rec: -2236465.00 | Epsilon: 0.356 | Vaciado: 3895s
#   Ep 679 | Rec: -1875606.00 | Epsilon: 0.356 | Vaciado: 3755s
#   Ep 680 | Rec: -1804569.00 | Epsilon: 0.356 | Vaciado: 3840s
#   Ep 681 | Rec: -2064895.00 | Epsilon: 0.356 | Vaciado: 3850s
#   Ep 682 | Rec: -1978248.00 | Epsilon: 0.355 | Vaciado: 3885s
#   Ep 683 | Rec: -1944342.00 | Epsilon: 0.355 | Vaciado: 3805s
#   Ep 684 | Rec: -1839685.00 | Epsilon: 0.355 | Vaciado: 4125s
#   Ep 685 | Rec: -2057622.00 | Epsilon: 0.355 | Vaciado: 3870s
#   Ep 686 | Rec: -1949654.00 | Epsilon: 0.355 | Vaciado: 3945s
#   Ep 687 | Rec: -1893160.00 | Epsilon: 0.355 | Vaciado: 4110s
#   Ep 688 | Rec: -1873074.00 | Epsilon: 0.354 | Vaciado: 3895s
#   Ep 689 | Rec: -2063900.00 | Epsilon: 0.354 | Vaciado: 3815s
#   Ep 690 | Rec: -2799960.00 | Epsilon: 0.354 | Vaciado: 4440s
#   Ep 691 | Rec: -2098239.00 | Epsilon: 0.354 | Vaciado: 4210s
#   Ep 692 | Rec: -2252844.00 | Epsilon: 0.354 | Vaciado: 3930s
#   Ep 693 | Rec: -1882272.00 | Epsilon: 0.354 | Vaciado: 3820s
#   Ep 694 | Rec: -1999584.00 | Epsilon: 0.353 | Vaciado: 3885s
#   Ep 695 | Rec: -2322750.00 | Epsilon: 0.353 | Vaciado: 4090s
#   Ep 696 | Rec: -2225826.00 | Epsilon: 0.353 | Vaciado: 4210s
#   Ep 697 | Rec: -2055378.00 | Epsilon: 0.353 | Vaciado: 4135s
#   Ep 698 | Rec: -2203048.00 | Epsilon: 0.353 | Vaciado: 3855s
#   Ep 699 | Rec: -1897495.00 | Epsilon: 0.352 | Vaciado: 4210s
#   Ep 700 | Rec: -2124833.00 | Epsilon: 0.352 | Vaciado: 3910s | Cobertura: 55.8%
#   Ep 701 | Rec: -2131759.00 | Epsilon: 0.352 | Vaciado: 4015s
#   Ep 702 | Rec: -2119458.00 | Epsilon: 0.352 | Vaciado: 3985s
#   Ep 703 | Rec: -2122761.00 | Epsilon: 0.352 | Vaciado: 3915s
#   Ep 704 | Rec: -1925699.00 | Epsilon: 0.352 | Vaciado: 3960s
#   Ep 705 | Rec: -2140847.00 | Epsilon: 0.351 | Vaciado: 3980s
#   Ep 706 | Rec: -2429209.00 | Epsilon: 0.351 | Vaciado: 4120s
#   Ep 707 | Rec: -2053485.00 | Epsilon: 0.351 | Vaciado: 3925s
#   Ep 708 | Rec: -1997939.00 | Epsilon: 0.351 | Vaciado: 3820s
#   Ep 709 | Rec: -2087944.00 | Epsilon: 0.351 | Vaciado: 3980s
#   Ep 710 | Rec: -1989646.00 | Epsilon: 0.351 | Vaciado: 3975s
#   Ep 711 | Rec: -2647064.00 | Epsilon: 0.350 | Vaciado: 4015s
#   Ep 712 | Rec: -2247069.00 | Epsilon: 0.350 | Vaciado: 3960s
#   Ep 713 | Rec: -2383088.00 | Epsilon: 0.350 | Vaciado: 3780s
#   Ep 714 | Rec: -2061162.00 | Epsilon: 0.350 | Vaciado: 3930s
#   Ep 715 | Rec: -2190572.00 | Epsilon: 0.350 | Vaciado: 4045s
#   Ep 716 | Rec: -2137429.00 | Epsilon: 0.350 | Vaciado: 3890s
#   Ep 717 | Rec: -2135794.00 | Epsilon: 0.349 | Vaciado: 3885s
#   Ep 718 | Rec: -1719087.00 | Epsilon: 0.349 | Vaciado: 4075s
#   Ep 719 | Rec: -2019077.00 | Epsilon: 0.349 | Vaciado: 3965s
#   Ep 720 | Rec: -1860880.00 | Epsilon: 0.349 | Vaciado: 3965s
#   Ep 721 | Rec: -1680089.00 | Epsilon: 0.349 | Vaciado: 3915s
#   Ep 722 | Rec: -2085097.00 | Epsilon: 0.348 | Vaciado: 4065s
#   Ep 723 | Rec: -2077850.00 | Epsilon: 0.348 | Vaciado: 4075s
#   Ep 724 | Rec: -2040955.00 | Epsilon: 0.348 | Vaciado: 3800s
#   Ep 725 | Rec: -2348979.00 | Epsilon: 0.348 | Vaciado: 3905s
#   Ep 726 | Rec: -2011797.00 | Epsilon: 0.348 | Vaciado: 3885s
#   Ep 727 | Rec: -1977559.00 | Epsilon: 0.348 | Vaciado: 3870s
#   Ep 728 | Rec: -2063306.00 | Epsilon: 0.347 | Vaciado: 4040s
#   Ep 729 | Rec: -2025562.00 | Epsilon: 0.347 | Vaciado: 4075s
#   Ep 730 | Rec: -2031544.00 | Epsilon: 0.347 | Vaciado: 3845s
#   Ep 731 | Rec: -1916946.00 | Epsilon: 0.347 | Vaciado: 3815s
#   Ep 732 | Rec: -2023349.00 | Epsilon: 0.347 | Vaciado: 3820s
#   Ep 733 | Rec: -2664527.00 | Epsilon: 0.347 | Vaciado: 4345s
#   Ep 734 | Rec: -2085374.00 | Epsilon: 0.346 | Vaciado: 3875s
#   Ep 735 | Rec: -2013744.00 | Epsilon: 0.346 | Vaciado: 3980s
#   Ep 736 | Rec: -2043537.00 | Epsilon: 0.346 | Vaciado: 3895s
#   Ep 737 | Rec: -1979499.00 | Epsilon: 0.346 | Vaciado: 3885s
#   Ep 738 | Rec: -2081119.00 | Epsilon: 0.346 | Vaciado: 3780s
#   Ep 739 | Rec: -1886469.00 | Epsilon: 0.346 | Vaciado: 3875s
#   Ep 740 | Rec: -1880108.00 | Epsilon: 0.345 | Vaciado: 3770s
#   Ep 741 | Rec: -1889042.00 | Epsilon: 0.345 | Vaciado: 3745s
#   Ep 742 | Rec: -2466332.00 | Epsilon: 0.345 | Vaciado: 3945s
#   Ep 743 | Rec: -1854092.00 | Epsilon: 0.345 | Vaciado: 3835s
#   Ep 744 | Rec: -1972317.00 | Epsilon: 0.345 | Vaciado: 4075s
#   Ep 745 | Rec: -2193015.00 | Epsilon: 0.344 | Vaciado: 4185s
#   Ep 746 | Rec: -2367201.00 | Epsilon: 0.344 | Vaciado: 3960s
#   Ep 747 | Rec: -1997333.00 | Epsilon: 0.344 | Vaciado: 3855s
#   Ep 748 | Rec: -2163662.00 | Epsilon: 0.344 | Vaciado: 4015s
#   Ep 749 | Rec: -2095919.00 | Epsilon: 0.344 | Vaciado: 3965s
#   Ep 750 | Rec: -2120687.00 | Epsilon: 0.344 | Vaciado: 4070s
#   Ep 751 | Rec: -2036813.00 | Epsilon: 0.343 | Vaciado: 4165s
#   Ep 752 | Rec: -1906225.00 | Epsilon: 0.343 | Vaciado: 3855s
#   Ep 753 | Rec: -2150609.00 | Epsilon: 0.343 | Vaciado: 3960s
#   Ep 754 | Rec: -2147293.00 | Epsilon: 0.343 | Vaciado: 3755s
#   Ep 755 | Rec: -2060544.00 | Epsilon: 0.343 | Vaciado: 4140s
#   Ep 756 | Rec: -2168802.00 | Epsilon: 0.343 | Vaciado: 3960s
#   Ep 757 | Rec: -1857572.00 | Epsilon: 0.342 | Vaciado: 3830s
#   Ep 758 | Rec: -3185065.00 | Epsilon: 0.342 | Vaciado: 4290s
#   Ep 759 | Rec: -2258137.00 | Epsilon: 0.342 | Vaciado: 4200s
#   Ep 760 | Rec: -2106521.00 | Epsilon: 0.342 | Vaciado: 3830s
#   Ep 761 | Rec: -1887379.00 | Epsilon: 0.342 | Vaciado: 3885s
#   Ep 762 | Rec: -1896054.00 | Epsilon: 0.342 | Vaciado: 3800s
#   Ep 763 | Rec: -2161283.00 | Epsilon: 0.341 | Vaciado: 3850s
#   Ep 764 | Rec: -1917180.00 | Epsilon: 0.341 | Vaciado: 3845s
#   Ep 765 | Rec: -2031109.00 | Epsilon: 0.341 | Vaciado: 4065s
#   Ep 766 | Rec: -1975313.00 | Epsilon: 0.341 | Vaciado: 3960s
#   Ep 767 | Rec: -1962329.00 | Epsilon: 0.341 | Vaciado: 3955s
#   Ep 768 | Rec: -2393556.00 | Epsilon: 0.341 | Vaciado: 4035s
#   Ep 769 | Rec: -1874537.00 | Epsilon: 0.340 | Vaciado: 3835s
#   Ep 770 | Rec: -2099217.00 | Epsilon: 0.340 | Vaciado: 3810s
# ...
#   Ep 1161 | Rec: -2151814.00 | Epsilon: 0.280 | Vaciado: 4145s
#   Ep 1162 | Rec: -2054266.00 | Epsilon: 0.280 | Vaciado: 3940s
#   Ep 1163 | Rec: -2266215.00 | Epsilon: 0.279 | Vaciado: 3880s
#   Ep 1164 | Rec: -2506212.00 | Epsilon: 0.279 | Vaciado: 4040s
#   Ep 1165 | Rec: -1921373.00 | Epsilon: 0.279 | Vaciado: 3885s
#   Ep 1166 | Rec: -2052922.00 | Epsilon: 0.279 | Vaciado: 3765s
#   Ep 1167 | Rec: -2535821.00 | Epsilon: 0.279 | Vaciado: 4300s
#   Ep 1168 | Rec: -2059947.00 | Epsilon: 0.279 | Vaciado: 4190s
#   Ep 1169 | Rec: -1801363.00 | Epsilon: 0.279 | Vaciado: 3840s
#   Ep 1170 | Rec: -1832324.00 | Epsilon: 0.279 | Vaciado: 3945s
#   Ep 1171 | Rec: -1833899.00 | Epsilon: 0.278 | Vaciado: 3865s
#   Ep 1172 | Rec: -1777421.00 | Epsilon: 0.278 | Vaciado: 3825s
#   Ep 1173 | Rec: -2526611.00 | Epsilon: 0.278 | Vaciado: 3935s
#   Ep 1174 | Rec: -1806216.00 | Epsilon: 0.278 | Vaciado: 3955s
#   Ep 1175 | Rec: -2489448.00 | Epsilon: 0.278 | Vaciado: 4040s
#   Ep 1176 | Rec: -1916133.00 | Epsilon: 0.278 | Vaciado: 3960s
#   Ep 1177 | Rec: -1596271.00 | Epsilon: 0.278 | Vaciado: 3880s
#   Ep 1178 | Rec: -2063686.00 | Epsilon: 0.277 | Vaciado: 4085s
#   Ep 1179 | Rec: -2151129.00 | Epsilon: 0.277 | Vaciado: 3990s
#   Ep 1180 | Rec: -1955779.00 | Epsilon: 0.277 | Vaciado: 3965s
#   Ep 1181 | Rec: -1872483.00 | Epsilon: 0.277 | Vaciado: 3915s
#   Ep 1182 | Rec: -2251182.00 | Epsilon: 0.277 | Vaciado: 4100s
#   Ep 1183 | Rec: -1967039.00 | Epsilon: 0.277 | Vaciado: 3880s
#   Ep 1184 | Rec: -2217339.00 | Epsilon: 0.277 | Vaciado: 3875s
#   Ep 1185 | Rec: -1937512.00 | Epsilon: 0.276 | Vaciado: 4030s
#   Ep 1186 | Rec: -2193491.00 | Epsilon: 0.276 | Vaciado: 4000s
#   Ep 1187 | Rec: -1760223.00 | Epsilon: 0.276 | Vaciado: 3920s
#   Ep 1188 | Rec: -1820792.00 | Epsilon: 0.276 | Vaciado: 3815s
#   Ep 1189 | Rec: -1848337.00 | Epsilon: 0.276 | Vaciado: 3950s
#   Ep 1190 | Rec: -2032513.00 | Epsilon: 0.276 | Vaciado: 3765s
#   Ep 1191 | Rec: -2061935.00 | Epsilon: 0.276 | Vaciado: 3950s
#   Ep 1192 | Rec: -1886033.00 | Epsilon: 0.275 | Vaciado: 4130s
#   Ep 1193 | Rec: -2060532.00 | Epsilon: 0.275 | Vaciado: 3965s
#   Ep 1194 | Rec: -2007520.00 | Epsilon: 0.275 | Vaciado: 4135s
#   Ep 1195 | Rec: -2106857.00 | Epsilon: 0.275 | Vaciado: 3745s
#   Ep 1196 | Rec: -1958534.00 | Epsilon: 0.275 | Vaciado: 3905s
#   Ep 1197 | Rec: -1958867.00 | Epsilon: 0.275 | Vaciado: 3870s
#   Ep 1198 | Rec: -1796549.00 | Epsilon: 0.275 | Vaciado: 3895s
#   Ep 1199 | Rec: -1958988.00 | Epsilon: 0.275 | Vaciado: 3940s
#   Ep 1200 | Rec: -2032380.00 | Epsilon: 0.274 | Vaciado: 3860s | Cobertura: 56.5%
#   Ep 1201 | Rec: -2125363.00 | Epsilon: 0.274 | Vaciado: 3870s
#   Ep 1202 | Rec: -2921477.00 | Epsilon: 0.274 | Vaciado: 4515s
#   Ep 1203 | Rec: -1712889.00 | Epsilon: 0.274 | Vaciado: 4095s
#   Ep 1204 | Rec: -1774758.00 | Epsilon: 0.274 | Vaciado: 3990s
#   Ep 1205 | Rec: -2197369.00 | Epsilon: 0.274 | Vaciado: 4085s
#   Ep 1206 | Rec: -2248771.00 | Epsilon: 0.274 | Vaciado: 3880s
#   Ep 1207 | Rec: -1766275.00 | Epsilon: 0.273 | Vaciado: 4070s
#   Ep 1208 | Rec: -2255938.00 | Epsilon: 0.273 | Vaciado: 4085s
#   Ep 1209 | Rec: -2156198.00 | Epsilon: 0.273 | Vaciado: 3915s
#   Ep 1210 | Rec: -1900412.00 | Epsilon: 0.273 | Vaciado: 3840s
#   Ep 1211 | Rec: -1904927.00 | Epsilon: 0.273 | Vaciado: 3820s
#   Ep 1212 | Rec: -1723249.00 | Epsilon: 0.273 | Vaciado: 3890s
#   Ep 1213 | Rec: -1781204.00 | Epsilon: 0.273 | Vaciado: 3900s
#   Ep 1214 | Rec: -1913563.00 | Epsilon: 0.272 | Vaciado: 3875s
#   Ep 1215 | Rec: -1919622.00 | Epsilon: 0.272 | Vaciado: 4030s
#   Ep 1216 | Rec: -1828004.00 | Epsilon: 0.272 | Vaciado: 3815s
#   Ep 1217 | Rec: -2445590.00 | Epsilon: 0.272 | Vaciado: 4350s
#   Ep 1218 | Rec: -1982517.00 | Epsilon: 0.272 | Vaciado: 3970s
#   Ep 1219 | Rec: -2249954.00 | Epsilon: 0.272 | Vaciado: 4465s
#   Ep 1220 | Rec: -1870295.00 | Epsilon: 0.272 | Vaciado: 3910s
#   Ep 1221 | Rec: -1847883.00 | Epsilon: 0.271 | Vaciado: 4050s
#   Ep 1222 | Rec: -2428272.00 | Epsilon: 0.271 | Vaciado: 4095s
#   Ep 1223 | Rec: -1952465.00 | Epsilon: 0.271 | Vaciado: 4175s
#   Ep 1224 | Rec: -1868073.00 | Epsilon: 0.271 | Vaciado: 4215s
#   Ep 1225 | Rec: -1932772.00 | Epsilon: 0.271 | Vaciado: 4020s
#   Ep 1226 | Rec: -2841406.00 | Epsilon: 0.271 | Vaciado: 4415s
#   Ep 1227 | Rec: -1931730.00 | Epsilon: 0.271 | Vaciado: 3915s
#   Ep 1228 | Rec: -2013743.00 | Epsilon: 0.271 | Vaciado: 4045s
#   Ep 1229 | Rec: -1753881.00 | Epsilon: 0.270 | Vaciado: 3800s
#   Ep 1230 | Rec: -1883986.00 | Epsilon: 0.270 | Vaciado: 3785s
#   Ep 1231 | Rec: -1807846.00 | Epsilon: 0.270 | Vaciado: 3950s
#   Ep 1232 | Rec: -1836527.00 | Epsilon: 0.270 | Vaciado: 3885s
#   Ep 1233 | Rec: -1876958.00 | Epsilon: 0.270 | Vaciado: 3870s
#   Ep 1234 | Rec: -2197101.00 | Epsilon: 0.270 | Vaciado: 3810s
#   Ep 1235 | Rec: -1929764.00 | Epsilon: 0.270 | Vaciado: 3795s
#   Ep 1236 | Rec: -1951645.00 | Epsilon: 0.269 | Vaciado: 3860s
#   Ep 1237 | Rec: -2316579.00 | Epsilon: 0.269 | Vaciado: 4025s
#   Ep 1238 | Rec: -2187309.00 | Epsilon: 0.269 | Vaciado: 3910s
#   Ep 1239 | Rec: -2189362.00 | Epsilon: 0.269 | Vaciado: 4240s
#   Ep 1240 | Rec: -1981364.00 | Epsilon: 0.269 | Vaciado: 3990s
#   Ep 1241 | Rec: -1787782.00 | Epsilon: 0.269 | Vaciado: 4070s
#   Ep 1242 | Rec: -1751300.00 | Epsilon: 0.269 | Vaciado: 3935s
#   Ep 1243 | Rec: -2071482.00 | Epsilon: 0.269 | Vaciado: 3935s
#   Ep 1244 | Rec: -1959285.00 | Epsilon: 0.268 | Vaciado: 3880s
#   Ep 1245 | Rec: -1797250.00 | Epsilon: 0.268 | Vaciado: 3790s
#   Ep 1246 | Rec: -2069844.00 | Epsilon: 0.268 | Vaciado: 4040s
#   Ep 1247 | Rec: -2100563.00 | Epsilon: 0.268 | Vaciado: 3955s
#   Ep 1248 | Rec: -1890289.00 | Epsilon: 0.268 | Vaciado: 3820s
#   Ep 1249 | Rec: -1730486.00 | Epsilon: 0.268 | Vaciado: 3860s
#   Ep 1250 | Rec: -1924862.00 | Epsilon: 0.268 | Vaciado: 3745s
#   Ep 1251 | Rec: -1809407.00 | Epsilon: 0.267 | Vaciado: 3980s
#   Ep 1252 | Rec: -1975619.00 | Epsilon: 0.267 | Vaciado: 4005s
#   Ep 1253 | Rec: -1984019.00 | Epsilon: 0.267 | Vaciado: 3845s
#   Ep 1254 | Rec: -1819905.00 | Epsilon: 0.267 | Vaciado: 3830s
#   Ep 1255 | Rec: -2120443.00 | Epsilon: 0.267 | Vaciado: 4010s
#   Ep 1256 | Rec: -1858684.00 | Epsilon: 0.267 | Vaciado: 3835s
#   Ep 1257 | Rec: -1854259.00 | Epsilon: 0.267 | Vaciado: 3785s
#   Ep 1258 | Rec: -2027192.00 | Epsilon: 0.267 | Vaciado: 4150s
#   Ep 1259 | Rec: -1768355.00 | Epsilon: 0.266 | Vaciado: 3950s
#   Ep 1260 | Rec: -2011935.00 | Epsilon: 0.266 | Vaciado: 3895s
#   Ep 1261 | Rec: -2183076.00 | Epsilon: 0.266 | Vaciado: 3930s
#   Ep 1262 | Rec: -1937323.00 | Epsilon: 0.266 | Vaciado: 3845s
#   Ep 1263 | Rec: -1899227.00 | Epsilon: 0.266 | Vaciado: 3920s
#   Ep 1264 | Rec: -2128121.00 | Epsilon: 0.266 | Vaciado: 3915s
#   Ep 1265 | Rec: -2025594.00 | Epsilon: 0.266 | Vaciado: 4005s
#   Ep 1266 | Rec: -1882949.00 | Epsilon: 0.265 | Vaciado: 3985s
#   Ep 1267 | Rec: -1963783.00 | Epsilon: 0.265 | Vaciado: 3870s
#   Ep 1268 | Rec: -1818826.00 | Epsilon: 0.265 | Vaciado: 3960s
#   Ep 1269 | Rec: -1811410.00 | Epsilon: 0.265 | Vaciado: 4015s
#   Ep 1270 | Rec: -2090207.00 | Epsilon: 0.265 | Vaciado: 4070s
#   Ep 1271 | Rec: -2016795.00 | Epsilon: 0.265 | Vaciado: 3935s
#   Ep 1272 | Rec: -1769299.00 | Epsilon: 0.265 | Vaciado: 3940s
#   Ep 1273 | Rec: -1809718.00 | Epsilon: 0.265 | Vaciado: 3895s
#   Ep 1274 | Rec: -2445981.00 | Epsilon: 0.264 | Vaciado: 4280s
#   Ep 1275 | Rec: -1778343.00 | Epsilon: 0.264 | Vaciado: 3835s
#   Ep 1276 | Rec: -1762036.00 | Epsilon: 0.264 | Vaciado: 3855s
#   Ep 1277 | Rec: -2014013.00 | Epsilon: 0.264 | Vaciado: 3780s
#   Ep 1278 | Rec: -2378804.00 | Epsilon: 0.264 | Vaciado: 3910s
#   Ep 1279 | Rec: -2048910.00 | Epsilon: 0.264 | Vaciado: 3910s
#   Ep 1280 | Rec: -2087283.00 | Epsilon: 0.264 | Vaciado: 4155s
#   Ep 1281 | Rec: -2321083.00 | Epsilon: 0.263 | Vaciado: 4135s
#   Ep 1282 | Rec: -1944510.00 | Epsilon: 0.263 | Vaciado: 4015s
#   Ep 1283 | Rec: -1927273.00 | Epsilon: 0.263 | Vaciado: 3910s
#   Ep 1284 | Rec: -1820598.00 | Epsilon: 0.263 | Vaciado: 3955s
#   Ep 1285 | Rec: -2079773.00 | Epsilon: 0.263 | Vaciado: 3930s
#   Ep 1286 | Rec: -2096826.00 | Epsilon: 0.263 | Vaciado: 4015s
#   Ep 1287 | Rec: -2262169.00 | Epsilon: 0.263 | Vaciado: 3870s
#   Ep 1288 | Rec: -1938821.00 | Epsilon: 0.263 | Vaciado: 3895s
#   Ep 1289 | Rec: -1949516.00 | Epsilon: 0.262 | Vaciado: 3895s
#   Ep 1290 | Rec: -1835505.00 | Epsilon: 0.262 | Vaciado: 4010s
#   Ep 1291 | Rec: -1970301.00 | Epsilon: 0.262 | Vaciado: 4075s
#   Ep 1292 | Rec: -1995098.00 | Epsilon: 0.262 | Vaciado: 4050s
#   Ep 1293 | Rec: -1874750.00 | Epsilon: 0.262 | Vaciado: 3930s
#   Ep 1294 | Rec: -2120662.00 | Epsilon: 0.262 | Vaciado: 3960s
#   Ep 1295 | Rec: -1869027.00 | Epsilon: 0.262 | Vaciado: 3905s
#   Ep 1296 | Rec: -1953564.00 | Epsilon: 0.262 | Vaciado: 3915s
#   Ep 1297 | Rec: -1912835.00 | Epsilon: 0.261 | Vaciado: 3735s
#   Ep 1298 | Rec: -1964352.00 | Epsilon: 0.261 | Vaciado: 3840s
#   Ep 1299 | Rec: -1931886.00 | Epsilon: 0.261 | Vaciado: 3915s
#   Ep 1300 | Rec: -1992527.00 | Epsilon: 0.261 | Vaciado: 3965s | Cobertura: 56.5%
#   Ep 1301 | Rec: -2083693.00 | Epsilon: 0.261 | Vaciado: 4365s
#   Ep 1302 | Rec: -1755415.00 | Epsilon: 0.261 | Vaciado: 3890s
#   Ep 1303 | Rec: -1892155.00 | Epsilon: 0.261 | Vaciado: 4320s
#   Ep 1304 | Rec: -2529173.00 | Epsilon: 0.260 | Vaciado: 4415s
#   Ep 1305 | Rec: -2117970.00 | Epsilon: 0.260 | Vaciado: 3980s
#   Ep 1306 | Rec: -1941952.00 | Epsilon: 0.260 | Vaciado: 3830s
#   Ep 1307 | Rec: -2123968.00 | Epsilon: 0.260 | Vaciado: 3805s
#   Ep 1308 | Rec: -1707103.00 | Epsilon: 0.260 | Vaciado: 3795s
#   Ep 1309 | Rec: -1979406.00 | Epsilon: 0.260 | Vaciado: 3865s
#   Ep 1310 | Rec: -2078850.00 | Epsilon: 0.260 | Vaciado: 3900s
#   Ep 1311 | Rec: -1847019.00 | Epsilon: 0.260 | Vaciado: 3825s
#   Ep 1312 | Rec: -1965197.00 | Epsilon: 0.259 | Vaciado: 3835s
#   Ep 1313 | Rec: -1836476.00 | Epsilon: 0.259 | Vaciado: 3810s
#   Ep 1314 | Rec: -1824514.00 | Epsilon: 0.259 | Vaciado: 3765s
#   Ep 1315 | Rec: -1988159.00 | Epsilon: 0.259 | Vaciado: 3855s
#   Ep 1316 | Rec: -1903848.00 | Epsilon: 0.259 | Vaciado: 3910s
#   Ep 1317 | Rec: -2018800.00 | Epsilon: 0.259 | Vaciado: 3815s
#   Ep 1318 | Rec: -2069843.00 | Epsilon: 0.259 | Vaciado: 3845s
#   Ep 1319 | Rec: -2243777.00 | Epsilon: 0.259 | Vaciado: 4070s
#   Ep 1320 | Rec: -1788606.00 | Epsilon: 0.258 | Vaciado: 3875s
#   Ep 1321 | Rec: -1766946.00 | Epsilon: 0.258 | Vaciado: 3995s
#   Ep 1322 | Rec: -2141778.00 | Epsilon: 0.258 | Vaciado: 3890s
#   Ep 1323 | Rec: -2008810.00 | Epsilon: 0.258 | Vaciado: 3890s
#   Ep 1324 | Rec: -2307695.00 | Epsilon: 0.258 | Vaciado: 4075s
#   Ep 1325 | Rec: -1787753.00 | Epsilon: 0.258 | Vaciado: 4000s
#   Ep 1326 | Rec: -1689118.00 | Epsilon: 0.258 | Vaciado: 3965s
#   Ep 1327 | Rec: -1846454.00 | Epsilon: 0.257 | Vaciado: 4060s
#   Ep 1328 | Rec: -1859312.00 | Epsilon: 0.257 | Vaciado: 4165s
#   Ep 1329 | Rec: -2168081.00 | Epsilon: 0.257 | Vaciado: 3810s
#   Ep 1330 | Rec: -2167883.00 | Epsilon: 0.257 | Vaciado: 3995s
#   Ep 1331 | Rec: -2166522.00 | Epsilon: 0.257 | Vaciado: 3855s
#   Ep 1332 | Rec: -1917734.00 | Epsilon: 0.257 | Vaciado: 3905s
#   Ep 1333 | Rec: -1960805.00 | Epsilon: 0.257 | Vaciado: 3815s
#   Ep 1334 | Rec: -1960222.00 | Epsilon: 0.257 | Vaciado: 3805s
#   Ep 1335 | Rec: -1800801.00 | Epsilon: 0.256 | Vaciado: 3880s
#   Ep 1336 | Rec: -1960371.00 | Epsilon: 0.256 | Vaciado: 3970s
#   Ep 1337 | Rec: -2000727.00 | Epsilon: 0.256 | Vaciado: 3775s
#   Ep 1338 | Rec: -2031797.00 | Epsilon: 0.256 | Vaciado: 3895s
#   Ep 1339 | Rec: -2423350.00 | Epsilon: 0.256 | Vaciado: 3875s
#   Ep 1340 | Rec: -2052142.00 | Epsilon: 0.256 | Vaciado: 3900s
#   Ep 1341 | Rec: -1713269.00 | Epsilon: 0.256 | Vaciado: 3945s
#   Ep 1342 | Rec: -2085106.00 | Epsilon: 0.256 | Vaciado: 3830s
#   Ep 1343 | Rec: -2139322.00 | Epsilon: 0.255 | Vaciado: 3895s
#   Ep 1344 | Rec: -2046161.00 | Epsilon: 0.255 | Vaciado: 3985s
#   Ep 1345 | Rec: -2181290.00 | Epsilon: 0.255 | Vaciado: 4205s
#   Ep 1346 | Rec: -2011195.00 | Epsilon: 0.255 | Vaciado: 4025s
#   Ep 1347 | Rec: -2067145.00 | Epsilon: 0.255 | Vaciado: 3970s
#   Ep 1348 | Rec: -2053397.00 | Epsilon: 0.255 | Vaciado: 4165s
#   Ep 1349 | Rec: -2496285.00 | Epsilon: 0.255 | Vaciado: 4315s
#   Ep 1350 | Rec: -2078622.00 | Epsilon: 0.255 | Vaciado: 3905s
#   Ep 1351 | Rec: -2164182.00 | Epsilon: 0.254 | Vaciado: 4310s
#   Ep 1352 | Rec: -1773203.00 | Epsilon: 0.254 | Vaciado: 4040s
#   Ep 1353 | Rec: -1722614.00 | Epsilon: 0.254 | Vaciado: 3865s
#   Ep 1354 | Rec: -2057444.00 | Epsilon: 0.254 | Vaciado: 4150s
#   Ep 1355 | Rec: -1781156.00 | Epsilon: 0.254 | Vaciado: 3975s
#   Ep 1356 | Rec: -2226315.00 | Epsilon: 0.254 | Vaciado: 4015s
#   Ep 1357 | Rec: -1768453.00 | Epsilon: 0.254 | Vaciado: 4130s
#   Ep 1358 | Rec: -2090765.00 | Epsilon: 0.254 | Vaciado: 3990s
#   Ep 1359 | Rec: -2081221.00 | Epsilon: 0.253 | Vaciado: 4240s
#   Ep 1360 | Rec: -1946864.00 | Epsilon: 0.253 | Vaciado: 3975s
#   Ep 1361 | Rec: -1773470.00 | Epsilon: 0.253 | Vaciado: 3830s
#   Ep 1362 | Rec: -2185240.00 | Epsilon: 0.253 | Vaciado: 4030s
#   Ep 1363 | Rec: -1760648.00 | Epsilon: 0.253 | Vaciado: 3880s
#   Ep 1364 | Rec: -1937872.00 | Epsilon: 0.253 | Vaciado: 3820s
#   Ep 1365 | Rec: -1894369.00 | Epsilon: 0.253 | Vaciado: 3995s
#   Ep 1366 | Rec: -1976512.00 | Epsilon: 0.253 | Vaciado: 3810s
#   Ep 1367 | Rec: -2170129.00 | Epsilon: 0.252 | Vaciado: 4050s
#   Ep 1368 | Rec: -1938441.00 | Epsilon: 0.252 | Vaciado: 3845s
#   Ep 1369 | Rec: -1988732.00 | Epsilon: 0.252 | Vaciado: 4190s
#   Ep 1370 | Rec: -1857660.00 | Epsilon: 0.252 | Vaciado: 3955s
#   Ep 1371 | Rec: -2110187.00 | Epsilon: 0.252 | Vaciado: 3990s
#   Ep 1372 | Rec: -2014650.00 | Epsilon: 0.252 | Vaciado: 3780s
#   Ep 1373 | Rec: -2393779.00 | Epsilon: 0.252 | Vaciado: 4020s
#   Ep 1374 | Rec: -1880727.00 | Epsilon: 0.251 | Vaciado: 3845s
#   Ep 1375 | Rec: -1926539.00 | Epsilon: 0.251 | Vaciado: 3960s
#   Ep 1376 | Rec: -2297209.00 | Epsilon: 0.251 | Vaciado: 4125s
#   Ep 1377 | Rec: -1880502.00 | Epsilon: 0.251 | Vaciado: 3970s
#   Ep 1378 | Rec: -2183488.00 | Epsilon: 0.251 | Vaciado: 4115s
#   Ep 1379 | Rec: -1931214.00 | Epsilon: 0.251 | Vaciado: 3845s
#   Ep 1380 | Rec: -1839115.00 | Epsilon: 0.251 | Vaciado: 4000s
#   Ep 1381 | Rec: -2063510.00 | Epsilon: 0.251 | Vaciado: 3840s
#   Ep 1382 | Rec: -1749637.00 | Epsilon: 0.250 | Vaciado: 3985s
#   Ep 1383 | Rec: -1837646.00 | Epsilon: 0.250 | Vaciado: 3980s
#   Ep 1384 | Rec: -2007130.00 | Epsilon: 0.250 | Vaciado: 4105s
#   Ep 1385 | Rec: -1896603.00 | Epsilon: 0.250 | Vaciado: 3890s
#   Ep 1386 | Rec: -1686275.00 | Epsilon: 0.250 | Vaciado: 3930s
#   Ep 1387 | Rec: -1910798.00 | Epsilon: 0.250 | Vaciado: 3965s
#   Ep 1388 | Rec: -2009595.00 | Epsilon: 0.250 | Vaciado: 3990s
#   Ep 1389 | Rec: -1781700.00 | Epsilon: 0.250 | Vaciado: 3865s
#   Ep 1390 | Rec: -1926151.00 | Epsilon: 0.249 | Vaciado: 4055s
#   Ep 1391 | Rec: -1977322.00 | Epsilon: 0.249 | Vaciado: 3940s
#   Ep 1392 | Rec: -1782182.00 | Epsilon: 0.249 | Vaciado: 3875s
#   Ep 1393 | Rec: -1831102.00 | Epsilon: 0.249 | Vaciado: 4100s
#   Ep 1394 | Rec: -2111418.00 | Epsilon: 0.249 | Vaciado: 3835s
#   Ep 1395 | Rec: -1940233.00 | Epsilon: 0.249 | Vaciado: 3910s
#   Ep 1396 | Rec: -2160304.00 | Epsilon: 0.249 | Vaciado: 4130s
#   Ep 1397 | Rec: -1935883.00 | Epsilon: 0.249 | Vaciado: 3905s
#   Ep 1398 | Rec: -2213625.00 | Epsilon: 0.248 | Vaciado: 3965s
#   Ep 1399 | Rec: -1814456.00 | Epsilon: 0.248 | Vaciado: 3985s
#   Ep 1400 | Rec: -1994691.00 | Epsilon: 0.248 | Vaciado: 3955s | Cobertura: 56.5%
# Cobertura estabilizada en episodio 1400 - deteniendo entrenamiento
#
# Modelo guardado en resultados/modelo_qlearning_exp2.pkl
#
# ============================================================
# ESTADISTICAS DEL ENTRENAMIENTO
# ============================================================
# Estados en Q-table: 244
# Total estados posibles: 432 (6/6/4/3 bins)
# Cobertura final: 56.5%
#
# Top 10 estados mas visitados:
#   (5, 5, 3, 0): 189771 visitas
#   (5, 5, 3, 1): 42316 visitas
#   (5, 5, 3, 2): 36099 visitas
#   (0, 0, 0, 0): 17269 visitas
#   (5, 5, 2, 0): 4773 visitas
#   (1, 0, 0, 0): 3189 visitas
#   (5, 0, 0, 0): 2827 visitas
#   (2, 0, 0, 0): 2733 visitas
#   (5, 5, 2, 2): 2023 visitas
#   (5, 4, 2, 0): 1606 visitas
#
# Experience Replay Buffer:
# Tamaño actual: 2000 / 2000
# Total experiencias: 336829

# %%
# Curva de Aprendizaje
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")
plt.figure(figsize=(12, 6))
plt.plot(historial_recompensas, alpha=0.3, label="Recompensa por episodio", color="steelblue")

# Promedio móvil
if len(historial_recompensas) >= 50:
    window = 50
    promedio_movil = pd.Series(historial_recompensas).rolling(window=window).mean()
    plt.plot(promedio_movil, label=f"Promedio móvil ({window} eps)", color="darkblue", linewidth=2)

plt.xlabel("Episodio")
plt.ylabel("Recompensa")
plt.title("Curva de Aprendizaje - Q-Learning con Experience Replay")
plt.legend()
plt.tight_layout()
plt.show()

# %%
args = get_args()
ruta_modelo = os.path.join(OUT_FOLDER, "ql_rec_queue.pkl")

print(f"Cargando modelo: {ruta_modelo}")
with open(ruta_modelo, 'rb') as f:
    q_table_entrenada = pickle.load(f)

print(f"Estados en Q-table: {len(q_table_entrenada)}")

# ========== CONFIGURACION DE EVALUACION ==========
USAR_FALLBACK = True  # True: estados no vistos -> 30s | False: estados no vistos -> aleatorio

env_eval = SumoEnvironment(
    net_file=args.net,
    route_file=args.route,
    out_csv_name=os.path.join(OUT_FOLDER, "evaluacion_final"),
    single_agent=True,
    use_gui=False,
    num_seconds=args.num_seconds,
    delta_time=5,
    yellow_time=3,
    min_green=5,
    time_to_teleport=-1,
    additional_sumo_cmd=f"-W --no-step-log --tripinfo-output {os.path.join(OUT_FOLDER, 'tripinfo_final.xml')}"
)

env_eval = VariableGreenWrapper(env_eval, delta_time=5)
env_eval = TrafficStateWrapper(env_eval)

obs, _ = env_eval.reset()
try:

    exploracion_nula = EpsilonGreedy(initial_epsilon=0.0, min_epsilon=0.0, decay=1.0)
    replay_buffer_eval = ReplayBuffer(buffer_size=2000)
    agente_eval = QLAgentConVisitas(
        starting_state=obs,
        state_space=env_eval.observation_space,
        action_space=env_eval.action_space,
        alpha=0.0,
        gamma=args.gamma,
        exploration_strategy=exploracion_nula,
        replay_buffer=replay_buffer_eval,
        batch_size=64,
        update_freq=4
    )
    agente_eval.q_table = q_table_entrenada

    DURACIONES = VariableGreenWrapper.DURACIONES
    N_ACCIONES = len(DURACIONES)

    def elegir_accion(q_table, estado, n_acciones):
        if estado in q_table:
            return int(np.argmax(q_table[estado]))
        if USAR_FALLBACK:
            return n_acciones // 2  # 30s: accion de emergencia
        return int(np.random.randint(n_acciones))  # aleatorio

    modo = "FALLBACK (30s)" if USAR_FALLBACK else "ALEATORIO"
    print(f"Ejecutando evaluacion en modo: {modo}")

    done = False
    datos_recolectados = []

    while not done:
        estado_actual = tuple(agente_eval.state)
        accion = elegir_accion(agente_eval.q_table, estado_actual, N_ACCIONES)
        next_obs, reward, terminated, truncated, info = env_eval.step(accion)

        datos_recolectados.append(info)
        agente_eval.state = next_obs

        if env_eval.unwrapped.sumo.simulation.getMinExpectedNumber() == 0:
            tiempo_final = env_eval.unwrapped.sim_step
            print(f"Evaluacion completada. Red vaciada en {tiempo_final:.1f}s")
            break

        done = terminated or truncated

finally:
    env_eval.close()

df_metricas = pd.DataFrame(datos_recolectados)
ruta_csv = os.path.join(OUT_FOLDER, "dataset_sumo.csv")
os.makedirs(OUT_FOLDER, exist_ok=True)
df_metricas.to_csv(ruta_csv, index=False)

print(f"CSV exportado: {ruta_csv}")
print(f"XML generado: {os.path.join(OUT_FOLDER, 'tripinfo_final.xml')}")

# %%
df_metricas = pd.read_csv(os.path.join(OUT_FOLDER, "metricas.csv"))
print(f"Registros cargados: {len(df_metricas)}")
# Out:
# Registros cargados: 619

# %%
sns.set_theme(style="whitegrid")
plt.rcParams.update({'font.size': 12})

ruta_xml = os.path.join(OUT_FOLDER, "tripinfo.xml")
df_trips = pd.read_xml(ruta_xml)

for col in ['depart', 'waitingTime', 'timeLoss']:
    df_trips[col] = pd.to_numeric(df_trips[col])

fig, axs = plt.subplots(3, 1, figsize=(14, 15))
fig.tight_layout(pad=6.0)
fig.suptitle('Experimento 2: Q-Learning Discreto (6/6/4/3)', fontsize=16, fontweight='bold', y=1.02)

sns.scatterplot(x=df_trips['depart'], y=df_trips['waitingTime'], alpha=0.4, color='darkorange', s=20, ax=axs[0])
sns.lineplot(x=df_trips['depart'], y=df_trips['waitingTime'].rolling(50).mean(), color='black', label='Media movil', ax=axs[0])
axs[0].set_title("1. Tiempo de Espera por Vehiculo")
axs[0].set_xlabel("Segundo de ingreso")
axs[0].set_ylabel("Tiempo de Espera (s)")
axs[0].legend()

sns.scatterplot(x=df_trips['depart'], y=df_trips['timeLoss'], alpha=0.4, color='crimson', s=20, ax=axs[1])
sns.lineplot(x=df_trips['depart'], y=df_trips['timeLoss'].rolling(50).mean(), color='black', label='Media movil', ax=axs[1])
axs[1].set_title("2. Tiempo Perdido por Vehiculo")
axs[1].set_xlabel("Segundo de ingreso")
axs[1].set_ylabel("Tiempo Perdido (s)")
axs[1].legend()

axs[2].plot(df_metricas['step'], df_metricas['system_total_stopped'], color='darkblue', linewidth=2)
axs[2].fill_between(df_metricas['step'], df_metricas['system_total_stopped'], color='darkblue', alpha=0.2)
axs[2].set_title("3. Longitud de Cola en Interseccion")
axs[2].set_xlabel("Segundo de Simulacion")
axs[2].set_ylabel("Vehiculos en Cola")

plt.show()

# %%
for col in ['waitingTime', 'timeLoss', 'routeLength', 'duration']:
    df_trips[col] = pd.to_numeric(df_trips[col])

df_trips['velocidad_kmh'] = (df_trips['routeLength'] / df_trips['duration']) * 3.6

promedio_espera = df_trips['waitingTime'].mean()
maximo_espera = df_trips['waitingTime'].max()
promedio_perdido = df_trips['timeLoss'].mean()
maximo_perdido = df_trips['timeLoss'].max()
velocidad_media = df_trips['velocidad_kmh'].mean()
total_vehiculos = len(df_trips)
cola_promedio = df_metricas['system_total_stopped'].mean()
cola_maxima = df_metricas['system_total_stopped'].max()

print("=" * 50)
print("  METRICAS: Experimento 2 - Q-Learning Discreto")
print("=" * 50)
print("\n--- Rendimiento General ---")
print(f"Total vehiculos: {total_vehiculos}")
print(f"Velocidad promedio: {velocidad_media:.2f} km/h")
print("\n--- Demora Vehicular ---")
print(f"Tiempo espera promedio: {promedio_espera:.2f} s")
print(f"Tiempo espera maximo: {maximo_espera:.2f} s")
print(f"Tiempo perdido promedio: {promedio_perdido:.2f} s")
print(f"Tiempo perdido maximo: {maximo_perdido:.2f} s")
print("\n--- Ocupacion Interseccion ---")
print(f"Cola promedio: {cola_promedio:.2f} vehiculos")
print(f"Cola maxima: {cola_maxima} vehiculos")
print("=" * 50)

display(df_trips[['id', 'depart', 'duration', 'waitingTime', 'timeLoss']].head())
# Out:
# ==================================================
#   METRICAS: Experimento 2 - Q-Learning Discreto
# ==================================================
#
# --- Rendimiento General ---
# Total vehiculos: 2418
# Velocidad promedio: 14.53 km/h
#
# --- Demora Vehicular ---
# Tiempo espera promedio: 38.28 s
# Tiempo espera maximo: 100.00 s
# Tiempo perdido promedio: 126.81 s
# Tiempo perdido maximo: 209.65 s
#
# --- Ocupacion Interseccion ---
# Cola promedio: 26.80 vehiculos
# Cola maxima: 41 vehiculos
# ==================================================
#       id  depart  duration  waitingTime  timeLoss
# 0  veh_0   112.0      97.0         41.0     52.65
# 1  veh_1   154.0      74.0         13.0     23.29
# 2  veh_2   179.0      52.0          0.0      7.16
# 3  veh_3   179.0      65.0         11.0     20.60
# 4  veh_4   195.0      64.0         10.0     19.27
